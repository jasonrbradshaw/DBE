# %% [markdown]
# Kynan Ly (https://github.com/TAPoR-3-Tools/Tapor-Coding-Tools/blob/master/tapor_coding_tools/visualization/Multiple%20correspondence%20analysis%20and%20content%20analysis/Multiple%20Correspondence%20Analysis%20and%20Content%20Analysis.ipynb)

# %%
# Import helper libraries
import os
import nltk
import csv
import math

# Import panda / panda related content 
import pandas as pd
from pandas import read_table
import numpy as np

# Import MCA and matplot
from mca import *
from matplotlib import pyplot as plt

# Ensure we can see plots inside Jupyter notebook
# %matplotlib inline

# %%
# Set path to the file with novels
path = "./Clean"

# Save all the titles of the texts
textName = []

# Save all the content of the texts
textContent = []

# Go to the directory with all the text files
for filename in os.listdir(path):
    
    # Add the file name and remove the file type (in this case ".txt")
    textName.append(filename[:-4])
    
    # Open each file and add all the content 
    with open(path + '/' + filename, "r", encoding="utf8") as file:
         fileContent = file.read()

    # Add the content of the file
    textContent.append(fileContent)

# %%
# Define cleaning tokenize function
def cleaning_tokenize_Text(text):
    # Tokenize the text and set it to lower case
    tokens = nltk.word_tokenize(text.lower())
    
    # Remove all non-words
    tokens = [word for word in tokens if word[0].isalpha()]
    return tokens

# %%
# List to hold the results
text_clean_tokenized = []

# Iterate through all the text
for novel in textContent:
    # Clean the text
    text_clean_tokenized.append(cleaning_tokenize_Text(novel))

# %% [markdown]
# Working with General Inquirer Category
# Before we can move forward we are going to need to define a few functions and load in the General Inquirer Categories (that can be found here: http://www.wjh.harvard.edu/~inquirer/spreadsheet_guide.htm).
#
# In this this notebook we will be conducting context analysis on the tokenized and cleaned corpus. This is done by looking at each token and seeing what category (if any) it belongs to as outlined in the General Inquirer Categories.
#
# Note:
# In this notebook we are going to simplify the use of the General Inquirer Category. This is because in the General Inquirer Category they have different categories depending on how the word is used. Therefore, in this notebook all edition of each word is collapsed into one row that encompass all categories each edition possesses.

# %%
# The csv name of the inquirer dictionary
csvFile = "inquirerbasic.csv"

# Create a list of rows to hold the values
listOfRows = []

# Reading the csv 
with open(csvFile, 'r') as file: # This makes sure that file is closed after reading
    data = csv.reader(file)
    
    # For every row in the file save it
    for row in data:
        listOfRows.append(row)

# Close the file
file.closed

# Format the category
categories = listOfRows[0]

# We do not need the first 2 category (they have the word, and the source of it)
# The last two columns are description of the words in question. We also do not need that
# Note the csv also as additional 4 empty columns at the end (that is why we have -6)
categories = categories[2:len(categories)-6]

# Check on how many categories
print("Length of category " + str(len(categories)))

# Print out the first 5 categories
print(categories[:5])
# Out:
# Length of category 182
# ['Positiv', 'Negativ', 'Pstv', 'Affil', 'Ngtv']

# %% [markdown]
# General Inquirer Category Helper Functions
# Below are helper functions that help categorize the tokenized text in the corresponding categories.

# %%
# Set all the categories of a word into a set if that word did not exist already
def new_attribute_set(row):
    # The reason for a set because it is faster to load
    attributeSet = set()
    
    # If you belong to a category add it into the set
    for element in row:
        if element != "":
            attributeSet.add(element)
    return attributeSet;

# Combine with pre-existing set with any new additions
def combine_attribute_set(row, oldset):
    # The reason for a set because it is faster to load
    newSet = set()
    
    # If you belong to a category add it into the set
    for element in row:
        if element != "":
            newSet.add(element)
    
    # Return a new updated set
    return (oldset | newSet)

# Assign every word with the categories (in a set)
def get_dictionary_list(listOfRows,categories):
    returnDict = {}

    # For every row create the set of categories that belong to it
    for row in listOfRows:
        
        # Reduce the word to the base. This is because the csv has LOVE#1, LOVE#2 to symbolize different meanings
        # In this anaylsis we are going to collapse them together
        word = row[0].split("#", 1)[0]
    
        # Check to see if the word is in the dictionary already
        if word in returnDict:
            returnDict[word] = combine_attribute_set(row[2:len(categories)-2], returnDict[word])
        else:
            returnDict[word] = new_attribute_set(row[2:len(categories)-2])
        
    return returnDict

# Creates the columns we need and fills them with how many of each category the text belongs to
def update_values_category(dataframe):
    # Finds and counts all the categories it belongs to
    resultDictionary = find_category(dataframe["tokens"])
    # Iterate through the results
    for k, v in resultDictionary.items():
        # Create columns for every category
        dataframe[k] = v
    return dataframe

# Looks through the tokens and increments the appropriate categories that it belongs to
def find_category(tokens):
    # Set all categories to 0 as default
    tweetCategories = {el:0 for el in categories}
    # Iterate through all tokens
    for element in tokens:
        # If it exists increment the value
        if element.upper() in dictWords:
            inside = dictWords[element.upper()]
    
            # Increment the category
            for element in inside:
                tweetCategories[element] += 1
    
    return tweetCategories

# %%
# Create dictionary of words and their respective categories
dictWords = get_dictionary_list(listOfRows[1:], categories)

# Have a look at the dictionary
dictWords
# Out:
# {'ABIDE': {'Active', 'Affil', 'Doctrin', 'IAV', 'Positiv'},
#  'ABILITY': {'ABS', 'Abs@', 'EVAL', 'MeansLw', 'Positiv', 'Strong', 'Virtue'},
#  'ABLE': {'EVAL', 'MeansLw', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'ABOUND': {'IAV', 'Increas', 'Passive', 'Positiv'},
#  'ABSOLVE': {'Active', 'ComForm', 'IAV', 'Positiv', 'SocRel'},
#  'ABSORBENT': {'Increas', 'IndAdj', 'Positiv'},
#  'ABSORPTION': {'Affil', 'Increas', 'Positiv'},
#  'ABUNDANCE': {'ECON',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quan',
#   'Strong',
#   'WltOth',
#   'WltTot'},
#  'ABUNDANT': {'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quan',
#   'Strong',
#   'WltOth',
#   'WltTot'},
#  'ACCEDE': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot'},
#  'ACCENTUATE': {'Active', 'IAV', 'Ovrst', 'Positiv'},
#  'ACCEPT': {'IAV', 'Passive', 'PosAff', 'Positiv', 'Pstv', 'SocRel', 'Submit'},
#  'ACCEPTABLE': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'ACCEPTANCE': {'Affil', 'Passive', 'PosAff', 'Positiv', 'Pstv', 'SocRel'},
#  'ACCESSIBLE': {'IPadj', 'Positiv', 'Virtue'},
#  'ACCESSION': {'Increas', 'Positiv', 'Strong'},
#  'ACCLAIM': {'ComForm', 'Positiv', 'Virtue'},
#  'ACCLAMATION': {'ComForm', 'Positiv', 'Virtue'},
#  'ACCOLADE': {'ComForm', 'Positiv', 'Virtue'},
#  'ACCOMMODATE': {'Active',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Vary'},
#  'ACCOMMODATION': {'PLACE', 'Positiv', 'PowCoop', 'PowTot', 'Virtue'},
#  'ACCOMPANIMENT': {'Positiv', 'SocRel'},
#  'ACCOMPLISH': {'Active',
#   'Complet',
#   'EndsLw',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'ACCOMPLISHMENT': {'Active',
#   'EndsLw',
#   'Goal',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'ACCORD': {'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'PosAff',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'TrnGain'},
#  'ACCORDANCE': {'Know', 'Positiv', 'PowCoop', 'PowTot', 'Pstv'},
#  'ACCOUNTABLE': {'Causal', 'IndAdj', 'Positiv'},
#  'ACCRUE': {'Active', 'DAV', 'ECON', 'Econ@', 'Increas', 'Positiv'},
#  'ACCURACY': {'ABS',
#   'Abs@',
#   'EnlOth',
#   'EnlTot',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'ACCURATE': {'EnlOth', 'EnlTot', 'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'ACCURATENESS': {'Ovrst', 'Positiv', 'Virtue'},
#  'ACHIEVE': {'Active',
#   'Complet',
#   'EndsLw',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'ACHIEVEMENT': {'Active', 'EndsLw', 'Goal', 'Positiv', 'Power', 'Pstv'},
#  'ACKNOWLEDGEMENT': {'ComForm', 'Ovrst', 'Positiv'},
#  'ACQUAINT': {'EnlGain', 'EnlTot', 'IAV', 'Positiv', 'Pstv', 'Solve'},
#  'ACQUAINTANCE': {'AffOth',
#   'AffTot',
#   'Affil',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Role'},
#  'ACQUIT': {'DAV', 'Legal', 'Positiv', 'Solve'},
#  'ACQUITTAL': {'Legal', 'Positiv', 'Solve'},
#  'ACTUAL': {'Ovrst', 'Positiv', 'Pstv', 'SureLw', 'Virtue'},
#  'ACTUALITY': {'Doctrin', 'Positiv', 'Pstv', 'SureLw', 'Virtue'},
#  'ADAMANT': {'Arousal', 'IndAdj', 'Know', 'Positiv', 'Strong'},
#  'ADAPTABILITY': {'Positiv', 'Strong', 'Vary', 'Virtue'},
#  'ADAPTABLE': {'IndAdj', 'Positiv', 'Strong', 'Vary', 'Virtue'},
#  'ADAPTATION': {'Positiv', 'Strong', 'Vary', 'Virtue'},
#  'ADAPTIVE': {'IndAdj', 'Positiv', 'Strong', 'Vary', 'Virtue'},
#  'ADEPT': {'EVAL', 'Positiv', 'Pstv', 'SklOth', 'SklToT', 'Strong', 'Virtue'},
#  'ADEPTNESS': {'Positiv', 'Strong', 'Virtue'},
#  'ADEQUATE': {'EVAL', 'EndsLw', 'Positiv', 'Pstv', 'Undrst', 'Virtue'},
#  'ADHERENCE': {'Affil', 'Positiv', 'RcEthic', 'RcTot'},
#  'ADHERENT': {'Affil', 'IndAdj', 'Positiv'},
#  'ADHESION': {'Positiv', 'Rel'},
#  'ADHESIVE': {'IndAdj', 'Positiv', 'Rel'},
#  'ADJUNCT': {'Increas', 'Positiv', 'Rel'},
#  'ADJUST': {'IAV',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Submit',
#   'TrnGain',
#   'Virtue',
#   'WlbPsyc',
#   'WlbTot',
#   'Work'},
#  'ADJUSTABLE': {'IndAdj', 'Positiv', 'Vary'},
#  'ADJUSTMENT': {'Passive', 'Positiv', 'Pstv', 'Virtue'},
#  'ADMIRABLE': {'Eval@', 'IPadj', 'Positiv', 'RcTot', 'RspOth', 'Virtue'},
#  'ADMIRATION': {'EMOT',
#   'Pleasur',
#   'Positiv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'ADMIRE': {'Affil',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'SV',
#   'Submit'},
#  'ADMIRER': {'EMOT', 'HU', 'Positiv', 'Strong'},
#  'ADMIT': {'ComForm',
#   'DAV',
#   'IAV',
#   'Ovrst',
#   'Passive',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'RspLoss',
#   'RspTot',
#   'SocRel',
#   'Submit',
#   'Weak'},
#  'ADMITTANCE': {'Active', 'Positiv', 'Travel'},
#  'ADORABLE': {'Eval@', 'IndAdj', 'Positiv', 'Virtue'},
#  'ADORE': {'Active', 'EMOT', 'Pleasur', 'Positiv', 'SV'},
#  'ADORN': {'Active', 'Eval@', 'IAV', 'Positiv', 'Strong'},
#  'ADORNMENT': {'Eval@', 'Positiv', 'Virtue'},
#  'ADROIT': {'IndAdj', 'Positiv', 'Strong', 'Virtue'},
#  'ADROITLY': {'Positiv', 'Strong', 'Virtue'},
#  'ADULATION': {'ComForm', 'EMOT', 'Eval@', 'Pleasur', 'Positiv', 'Strong'},
#  'ADULT': {'HU',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'Strong',
#   'Virtue',
#   'WlbPt',
#   'WlbTot'},
#  'ADVANCE': {'Active',
#   'EndsLw',
#   'IAV',
#   'Means',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Time@',
#   'Travel',
#   'Virtue'},
#  'ADVANCEMENT': {'EndsLw', 'Increas', 'Positiv', 'Pstv'},
#  'ADVANTAGE': {'ABS',
#   'Abs@',
#   'ECON',
#   'MeansLw',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'ADVANTAGEOUS': {'MeansLw', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'ADVENT': {'Begin', 'Positiv'},
#  'ADVENTURESOME': {'Active', 'IndAdj', 'Positiv', 'Strong'},
#  'ADVENTUROUS': {'Active', 'IndAdj', 'PosAff', 'Positiv', 'Strong'},
#  'ADVISABLE': {'Eval@', 'IPadj', 'Know', 'PosAff', 'Positiv', 'Quality'},
#  'ADVOCACY': {'Affil', 'ComForm', 'Positiv'},
#  'AFFABILITY': {'Positiv', 'Virtue'},
#  'AFFABLE': {'IPadj', 'Positiv', 'Virtue'},
#  'AFFECTION': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'EMOT',
#   'Positiv',
#   'Pstv'},
#  'AFFECTIONATE': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'EMOT',
#   'Positiv',
#   'Pstv'},
#  'AFFILIATE': {'Active', 'Affil', 'IAV', 'Positiv', 'PowCoop', 'PowTot'},
#  'AFFILIATION': {'Affil', 'Positiv'},
#  'AFFINITY': {'Positiv', 'Strong', 'Virtue'},
#  'AFFIRM': {'ComForm', 'IAV', 'Positiv', 'Power', 'Pstv', 'Strong', 'TrnGain'},
#  'AFFIRMATION': {'ComForm', 'Eval@', 'Positiv'},
#  'AFFIRMATIVE': {'Positiv'},
#  'AFFIX': {'Active', 'Affil', 'DAV', 'Exert', 'Positiv'},
#  'AFFLUENCE': {'Econ@', 'Positiv', 'Quality', 'WltOth', 'WltTot'},
#  'AFFLUENT': {'Econ@', 'IndAdj', 'Positiv', 'Quality'},
#  'AFLOAT': {'Econ@', 'IndAdj', 'Positiv', 'Strong'},
#  'AGGREGATE': {'Positiv', 'Quan'},
#  'AGGREGATION': {'Positiv', 'Quan'},
#  'AGILE': {'IndAdj', 'Positiv', 'Strong', 'Virtue'},
#  'AGILITY': {'Positiv', 'Strong', 'Virtue'},
#  'AGREEABLE': {'ComForm', 'EVAL', 'Positiv', 'PowCoop', 'PowTot', 'Pstv'},
#  'AGREEMENT': {'Affil',
#   'COM',
#   'ComForm',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong'},
#  'AID': {'Active',
#   'Affil',
#   'IAV',
#   'MeansLw',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'ALERTNESS': {'Positiv', 'Think', 'Virtue'},
#  'ALIGHT': {'IndAdj', 'Ovrst', 'Positiv', 'Virtue'},
#  'ALIVE': {'Active',
#   'NatrPro',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'ALLEGIANCE': {'AffOth', 'AffTot', 'Affil', 'Positiv', 'Virtue'},
#  'ALLEVIATE': {'Active',
#   'Affil',
#   'Decreas',
#   'Exert',
#   'IAV',
#   'Positiv',
#   'TrnGain'},
#  'ALLIANCE': {'COLL',
#   'HU',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'ALLIED': {'Affil',
#   'IAV',
#   'Polit@',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'ALLIES': {'Affil', 'HU', 'Positiv', 'Role', 'SocRel'},
#  'ALLOW': {'IAV',
#   'Passive',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Solve',
#   'TranLw'},
#  'ALLOWABLE': {'Eval@', 'IPadj', 'Positiv', 'Quality'},
#  'ALLOWANCE': {'Econ@', 'Positiv', 'Quan', 'WltOth', 'WltTot'},
#  'ALLURE': {'Positiv', 'Virtue'},
#  'ALLY': {'Affil',
#   'HU',
#   'IAV',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Role',
#   'SocRel',
#   'Strong'},
#  'ALMIGHTY': {'EMOT',
#   'IndAdj',
#   'Positiv',
#   'Power',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'ALTRUISTIC': {'Affil', 'Fetch', 'IPadj', 'Positiv', 'Virtue'},
#  'AMAZEMENT': {'Positiv', 'Power', 'Strong'},
#  'AMAZING': {'IndAdj', 'Ovrst', 'Positiv', 'Power', 'Strong'},
#  'AMELIORATE': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'TrnGain'},
#  'AMENABLE': {'Affil', 'IndAdj', 'Positiv', 'Vary', 'Virtue'},
#  'AMENITY': {'Object', 'Positiv'},
#  'AMIABILITY': {'Affil', 'Positiv', 'Virtue'},
#  'AMIABLE': {'Affil', 'IPadj', 'Positiv', 'Virtue'},
#  'AMICABLE': {'AffOth', 'AffTot', 'Affil', 'IPadj', 'Positiv', 'Virtue'},
#  'AMNESTY': {'Doctrin', 'Legal', 'Positiv', 'Power'},
#  'AMOUR': {'EMOT', 'Pleasur', 'Positiv'},
#  'AMPLE': {'EndsLw', 'Positiv', 'Pstv', 'Quan', 'Strong'},
#  'AMPLIFY': {'Active', 'DAV', 'Increas', 'Positiv', 'Strong'},
#  'AMPLY': {'Increas', 'Positiv', 'Strong'},
#  'AMUSE': {'Active', 'EMOT', 'IAV', 'Pleasur', 'Positiv', 'WlbGain', 'WlbTot'},
#  'AMUSEMENT': {'Pleasur', 'Positiv', 'WlbPsyc', 'WlbTot'},
#  'ANGEL': {'Affil', 'HU', 'Positiv', 'Relig', 'Role', 'Virtue'},
#  'ANGELIC': {'Affil', 'IndAdj', 'Positiv', 'Relig', 'Virtue'},
#  'ANOINT': {'Active', 'Affil', 'DAV', 'Exert', 'Positiv'},
#  'APOCALYPSE': {'Perceiv', 'Pleasur', 'Positiv', 'Think'},
#  'APPEAL': {'Affil',
#   'COM',
#   'ComForm',
#   'EndsLw',
#   'IAV',
#   'Legal',
#   'Passive',
#   'Pleasur',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Submit'},
#  'APPEASE': {'Active', 'IAV', 'Positiv', 'PowGain', 'PowTot', 'Submit'},
#  'APPEND': {'Active', 'DAV', 'Increas', 'Positiv'},
#  'APPLAUD': {'Active', 'ComForm', 'DAV', 'Eval@', 'Positiv'},
#  'APPLAUSE': {'COM', 'ComForm', 'Positiv', 'Pstv', 'RspOth', 'RspTot'},
#  'APPOINT': {'Active',
#   'DAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel'},
#  'APPRECIABLE': {'Ovrst', 'Perceiv', 'Positiv', 'Pstv', 'Strong'},
#  'APPRECIATE': {'Affil',
#   'Arousal',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'SV',
#   'Submit'},
#  'APPRECIATION': {'Affil',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot'},
#  'APPRECIATIVE': {'Eval@', 'IPadj', 'Pleasur', 'Positiv', 'SocRel'},
#  'APPREHEND': {'Active', 'DAV', 'Fetch', 'Positiv'},
#  'APPROACH': {'Active',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Travel'},
#  'APPROPRIATE': {'IAV',
#   'Ovrst',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'SocRel',
#   'Strong',
#   'Virtue',
#   'WltTot',
#   'WltTran'},
#  'APPROVAL': {'Affil',
#   'COM',
#   'ComForm',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot'},
#  'APPROVE': {'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'APT': {'Ovrst', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'APTITUDE': {'Positiv', 'Strong', 'Virtue'},
#  'ARBITER': {'Affil', 'ComForm', 'HU', 'Positiv', 'Role', 'SocRel', 'Solve'},
#  'ARBITRATE': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'SocRel',
#   'Solve'},
#  'ARBITRATION': {'Affil',
#   'ComForm',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'SocRel',
#   'Solve'},
#  'ARDENT': {'Affil', 'IndAdj', 'PosAff', 'Positiv', 'Power', 'Strong'},
#  'ARISEN': {'Begin', 'Increas', 'IndAdj', 'Positiv'},
#  'ARISTOCRACY': {'Econ@', 'HU', 'Positiv', 'Power', 'Role'},
#  'ARISTOCRAT': {'Econ@', 'HU', 'Positiv', 'Power', 'Role'},
#  'ARISTOCRATIC': {'Econ@', 'IndAdj', 'Positiv', 'Power'},
#  'ARREST': {'Active',
#   'DAV',
#   'EVAL',
#   'Exert',
#   'Hostile',
#   'Legal',
#   'Negativ',
#   'Ngtv',
#   'Ovrst',
#   'Positiv',
#   'PowLoss',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Stay',
#   'Strong',
#   'Virtue'},
#  'ART': {'Academ',
#   'COM',
#   'ComnObj',
#   'Doctrin',
#   'EnlOth',
#   'EnlTot',
#   'Exprsv',
#   'Object',
#   'Positiv',
#   'Pstv',
#   'SV',
#   'SklAsth',
#   'SklOth',
#   'SklToT'},
#  'ASCRIBE': {'Active',
#   'Affil',
#   'Doctrin',
#   'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv'},
#  'ASPIRATION': {'Goal', 'Positiv', 'Think'},
#  'ASPIRE': {'Active', 'EndsLw', 'Goal', 'Positiv', 'SV', 'Try'},
#  'ASSENT': {'Affil', 'ComForm', 'Positiv', 'PowOth', 'PowTot'},
#  'ASSERTION': {'Arousal', 'ComForm', 'Know', 'Positiv', 'Strong'},
#  'ASSET': {'Affil', 'MeansLw', 'Positiv', 'Strong'},
#  'ASSIST': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'ASSISTANCE': {'Active',
#   'Affil',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'ASSISTANT': {'Active', 'HU', 'Positiv', 'Pstv', 'Role', 'Submit'},
#  'ASSOCIATE': {'Active',
#   'AffGain',
#   'AffTot',
#   'ECON',
#   'Econ@',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'IAV',
#   'Passive',
#   'Positiv',
#   'PowPt',
#   'PowTot',
#   'Pstv',
#   'Rel',
#   'Role',
#   'Solve'},
#  'ASSOCIATION': {'Active',
#   'Affil',
#   'COLL',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'Know',
#   'Positiv',
#   'PowPt',
#   'PowTot',
#   'Pstv',
#   'Strong'},
#  'ASSURANCE': {'Affil',
#   'COM',
#   'ComForm',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain'},
#  'ASSURE': {'ComForm',
#   'Complet',
#   'EMOT',
#   'IAV',
#   'Ovrst',
#   'Pleasur',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong',
#   'SureLw',
#   'TrnGain'},
#  'ASSUREDLY': {'Ovrst', 'Positiv', 'Power', 'Pstv', 'Strong', 'SureLw'},
#  'ASTOUND': {'Active', 'Ovrst', 'Positiv', 'Power', 'SV', 'Strong'},
#  'ASTUTE': {'IndAdj', 'Know', 'Positiv', 'Virtue'},
#  'ATHLETIC': {'Exprsv', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'ATTACHMENT': {'Affil', 'EMOT', 'Pleasur', 'PosAff', 'Positiv', 'SocRel'},
#  'ATTAIN': {'Active', 'Complet', 'EndsLw', 'IAV', 'Positiv', 'Pstv', 'Strong'},
#  'ATTAINMENT': {'Active', 'Complet', 'EndsLw', 'Positiv', 'Pstv', 'Strong'},
#  'ATTEND': {'Active',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Submit',
#   'Travel',
#   'WlbGain',
#   'WlbTot',
#   'Work'},
#  'ATTENDANCE': {'Active', 'Positiv', 'Stay'},
#  'ATTENTIVE': {'Passive', 'Perceiv', 'Positiv', 'Pstv', 'Submit'},
#  'ATTRACT': {'Affil', 'IAV', 'Positiv', 'Pstv', 'SocRel', 'Strong'},
#  'ATTRACTION': {'Affil', 'Pleasur', 'Positiv', 'Pstv', 'Strong'},
#  'ATTRACTIVE': {'EVAL', 'EndsLw', 'Positiv', 'Pstv', 'Virtue'},
#  'ATTRACTIVENESS': {'Eval@', 'Positiv', 'Quality'},
#  'ATTUNE': {'IndAdj', 'Positiv', 'Solve', 'Think'},
#  'AUDIBLE': {'ComForm', 'IndAdj', 'Positiv', 'Strong'},
#  'AUGMENT': {'Active', 'IAV', 'Increas', 'Positiv', 'Pstv', 'TrnGain'},
#  'AUGMENTATION': {'Increas', 'Positiv'},
#  'AUSPICIOUS': {'Eval@', 'IndAdj', 'PosAff', 'Positiv', 'Quality'},
#  'AUTHENTIC': {'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'AUTHENTICITY': {'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'AUTHORITATIVE': {'Doctrin',
#   'IPadj',
#   'Legal',
#   'Ovrst',
#   'Positiv',
#   'PowAuth',
#   'PowTot',
#   'Power',
#   'Strong',
#   'Virtue'},
#  'AUTHORITY': {'EnlPt',
#   'EnlTot',
#   'Legal',
#   'Positiv',
#   'PowAuPt',
#   'PowAuth',
#   'PowTot',
#   'Power',
#   'Strong'},
#  'AUTONOMOUS': {'IPadj', 'Legal', 'Positiv', 'Power', 'Strong', 'Undrst'},
#  'AVAILABILITY': {'Positiv', 'Pstv', 'Virtue'},
#  'AVID': {'IndAdj', 'Ovrst', 'Positiv'},
#  'AWARD': {'Active', 'ComForm', 'IAV', 'Positiv', 'Power', 'Pstv', 'Strong'},
#  'AWARE': {'EnlOth',
#   'EnlTot',
#   'IndAdj',
#   'Know',
#   'Passive',
#   'Perceiv',
#   'Positiv',
#   'Strong'},
#  'AWARENESS': {'ABS',
#   'Abs@',
#   'EnlOth',
#   'EnlTot',
#   'Passive',
#   'Perceiv',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'BACK': {'Active',
#   'Affil',
#   'BodyPt',
#   'Fail',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowLoss',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Time@'},
#  'BACKBONE': {'Positiv', 'Power', 'Strong'},
#  'BACKER': {'Econ@',
#   'HU',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Role',
#   'Strong'},
#  'BACKING': {'Affil', 'Positiv'},
#  'BALL': {'BodyPt',
#   'Exprsv',
#   'Object',
#   'Positiv',
#   'Pstv',
#   'Ritual',
#   'RspOth',
#   'RspTot',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Tool',
#   'Virtue',
#   'WlbGain',
#   'WlbTot'},
#  'BALMY': {'IndAdj', 'Pleasur', 'Positiv'},
#  'BAPTISM': {'Affil', 'Doctrin', 'Positiv'},
#  'BAPTIZE': {'Active', 'Affil', 'DAV', 'Doctrin', 'Positiv'},
#  'BARGAIN': {'Active', 'ComForm', 'Econ@', 'IAV', 'Positiv', 'SocRel'},
#  'BASIC': {'Ovrst', 'Positiv', 'Pstv', 'Rel', 'SureLw', 'Virtue'},
#  'BEACON': {'EnlOth', 'EnlTot', 'Positiv', 'Virtue'},
#  'BEAUTEOUS': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'BEAUTIFY': {'Active', 'Eval@', 'IAV', 'Positiv', 'Strong'},
#  'BEAUTY': {'ABS', 'Abs@', 'Positiv', 'Pstv', 'SklAsth', 'SklToT', 'Virtue'},
#  'BEFIT': {'Eval@', 'IAV', 'Passive', 'PosAff', 'Positiv'},
#  'BEFITTING': {'Eval@', 'IndAdj', 'Passive', 'Positiv'},
#  'BEFRIEND': {'Active', 'Affil', 'IAV', 'Positiv', 'SocRel'},
#  'BEHALF': {'Affil', 'Positiv', 'Pstv', 'Virtue'},
#  'BELOVED': {'AffOth', 'AffTot', 'Affil', 'Arousal', 'Positiv', 'Pstv'},
#  'BENEFACTOR': {'Econ@', 'Fetch', 'HU', 'Positiv', 'Role', 'Virtue'},
#  'BENEFICENT': {'Eval@', 'IPadj', 'Positiv', 'Virtue'},
#  'BENEFICIAL': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'BENEFICIARY': {'Econ@', 'Exch', 'HU', 'Positiv', 'Role'},
#  'BENEFIT': {'Affil',
#   'COM',
#   'ComForm',
#   'ECON',
#   'Econ@',
#   'Goal',
#   'IAV',
#   'MeansLw',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain',
#   'WltOth',
#   'WltTot'},
#  'BENEVOLENCE': {'Econ@', 'PosAff', 'Positiv', 'Virtue'},
#  'BENEVOLENT': {'Econ@', 'IPadj', 'Positiv', 'Virtue'},
#  'BENIGN': {'Affil', 'Passive', 'Positiv', 'Power', 'Pstv', 'Virtue'},
#  'BEQUEATH': {'Active', 'DAV', 'Econ@', 'Exch', 'Positiv'},
#  'BEST': {'Compare', 'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'BESTOW': {'Active',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain'},
#  'BETROTH': {'Active', 'Econ@', 'Exch', 'IAV', 'Positiv'},
#  'BETROTHAL': {'Econ@', 'Exch', 'Positiv'},
#  'BETTER': {'Active',
#   'Compare',
#   'EVAL',
#   'IAV',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'RspGain',
#   'RspTot',
#   'Try',
#   'Virtue'},
#  'BLAMELESS': {'Eval@', 'IndAdj', 'Legal', 'Positiv', 'Virtue'},
#  'BLESS': {'Affil',
#   'ComForm',
#   'IAV',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'RcEnds',
#   'RcTot',
#   'Relig',
#   'SocRel',
#   'Virtue'},
#  'BLISS': {'EMOT', 'Pleasur', 'Positiv'},
#  'BLISSFUL': {'EMOT', 'Eval@', 'IndAdj', 'Pleasur', 'Positiv'},
#  'BLITHE': {'IndAdj', 'Pleasur', 'Positiv'},
#  'BLOOM': {'Active', 'Begin', 'IAV', 'Increas', 'Positiv'},
#  'BLOSSOM': {'Active', 'Begin', 'IAV', 'Increas', 'Positiv'},
#  'BOARD': {'Academ',
#   'COLL',
#   'COM',
#   'ComForm',
#   'ComnObj',
#   'ECON',
#   'Econ@',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'IAV',
#   'NegAff',
#   'Negativ',
#   'Ngtv',
#   'Object',
#   'Ovrst',
#   'POLIT',
#   'Positiv',
#   'PowAuPt',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Quality',
#   'RcEthic',
#   'RcTot',
#   'SureLw',
#   'Tool',
#   'Travel',
#   'Vice',
#   'Virtue',
#   'WlbPhys',
#   'WlbTot'},
#  'BOLDNESS': {'Positiv', 'Power', 'Strong', 'Virtue'},
#  'BOLSTER': {'Active', 'Affil', 'IAV', 'Increas', 'Positiv', 'Strong'},
#  'BONNY': {'Eval@', 'IndAdj', 'Positiv', 'Virtue'},
#  'BONUS': {'ComForm', 'ECON', 'Econ@', 'Positiv', 'Pstv', 'WltOth', 'WltTot'},
#  'BOOM': {'Econ@', 'Increas', 'Positiv', 'Strong'},
#  'BOOST': {'Active', 'IAV', 'Increas', 'Positiv', 'Pstv', 'Strong', 'TrnGain'},
#  'BOUNDLESS': {'Increas', 'IndAdj', 'Positiv', 'Quan', 'Strong'},
#  'BOUNTIFUL': {'Increas',
#   'IndAdj',
#   'Positiv',
#   'Quan',
#   'Strong',
#   'WltOth',
#   'WltTot'},
#  'BRAINY': {'IndAdj', 'Positiv', 'Think'},
#  'BRAVE': {'EVAL',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Strong',
#   'Virtue'},
#  'BRAVERY': {'Positiv', 'Power', 'RcEthic', 'RcTot', 'Strong', 'Virtue'},
#  'BREADWINNER': {'Econ@', 'HU', 'Positiv', 'Role', 'Work'},
#  'BRIGHT': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Quality'},
#  'BRIGHTNESS': {'Positiv', 'Pstv', 'Quality'},
#  'BRILLIANCE': {'Positiv', 'Pstv', 'Quality'},
#  'BRILLIANT': {'EVAL', 'Ovrst', 'PosAff', 'Positiv', 'Pstv', 'Quality'},
#  'BROTHERHOOD': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'BROTHERLY': {'Affil', 'IPadj', 'Positiv', 'SocRel'},
#  'BUOYANT': {'Affil', 'IndAdj', 'Positiv', 'Strong'},
#  'BUY': {'Active',
#   'DAV',
#   'ECON',
#   'Econ@',
#   'Exch',
#   'Positiv',
#   'Pstv',
#   'Virtue',
#   'WltOth',
#   'WltTot',
#   'WltTran'},
#  'CALL': {'Affil',
#   'COM',
#   'ComForm',
#   'DAV',
#   'Doctrin',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'SocRel',
#   'Solve'},
#  'CALM': {'EMOT',
#   'IAV',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'CALMNESS': {'EMOT', 'Pleasur', 'Positiv', 'Undrst'},
#  'CANDID': {'ComForm', 'EnlOth', 'EnlTot', 'IPadj', 'Positiv', 'Strong'},
#  'CANDOR': {'ComForm', 'Positiv', 'Strong'},
#  'CAPABILITY': {'Means', 'MeansLw', 'Positiv', 'Power', 'Pstv', 'Strong'},
#  'CAPABLE': {'MeansLw', 'Positiv', 'Power', 'Pstv', 'Strong', 'Virtue'},
#  'CAPITALIZE': {'Active',
#   'Econ@',
#   'IAV',
#   'Increas',
#   'Positiv',
#   'Power',
#   'Strong'},
#  'CAPTIVATION': {'Ovrst', 'Perceiv', 'Positiv', 'Think'},
#  'CARE': {'Active',
#   'AffGain',
#   'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'Positiv',
#   'Pstv',
#   'SV',
#   'SocRel',
#   'Undrst'},
#  'CAREFREE': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv'},
#  'CAREFUL': {'Positiv', 'Pstv', 'Undrst', 'Virtue'},
#  'CARESS': {'AffGain',
#   'AffTot',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel'},
#  'CASUAL': {'Passive', 'Positiv', 'Pstv', 'Undrst', 'Virtue'},
#  'CEASELESS': {'FREQ', 'IndAdj', 'Negate', 'Positiv'},
#  'CELEBRATE': {'Active', 'IAV', 'Pleasur', 'Positiv', 'RspOth', 'RspTot'},
#  'CELEBRATION': {'Active',
#   'Affil',
#   'Positiv',
#   'Pstv',
#   'Ritual',
#   'RspOth',
#   'RspTot'},
#  'CELEBRITY': {'HU', 'Ovrst', 'Positiv', 'Power', 'Role'},
#  'CEREMONIAL': {'Doctrin', 'IndAdj', 'Positiv'},
#  'CHAMP': {'HU', 'Positiv', 'Power', 'Role', 'Strong'},
#  'CHAMPION': {'Active',
#   'HU',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Role',
#   'SklPt',
#   'SklToT',
#   'Strong'},
#  'CHAMPIONSHIP': {'Positiv', 'Power', 'Strong'},
#  'CHARISMA': {'Positiv', 'Strong', 'Virtue'},
#  'CHARITABLE': {'AffOth',
#   'AffTot',
#   'Econ@',
#   'Exch',
#   'IPadj',
#   'Positiv',
#   'Virtue'},
#  'CHARITY': {'ECON', 'Econ@', 'Positiv', 'Pstv', 'Virtue'},
#  'CHARM': {'Affil',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'SocRel',
#   'Virtue'},
#  'CHASTE': {'IndAdj', 'Positiv', 'Virtue'},
#  'CHEER': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'WlbGain',
#   'WlbTot'},
#  'CHEERFUL': {'EMOT', 'Pleasur', 'Positiv', 'Pstv', 'WlbPsyc', 'WlbTot'},
#  'CHEERY': {'EMOT', 'Pleasur', 'Positiv', 'Pstv'},
#  'CHERISH': {'Affil',
#   'EndsLw',
#   'IAV',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Virtue'},
#  'CHERUB': {'HU', 'Positiv', 'Role', 'Virtue'},
#  'CHIC': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'CHIVALROUS': {'Doctrin', 'IPadj', 'Positiv', 'Virtue'},
#  'CHIVALRY': {'Doctrin', 'Positiv', 'Virtue'},
#  'CHOSEN': {'EndsLw', 'IAV', 'Passive', 'Positiv', 'Pstv', 'Solve', 'Virtue'},
#  'CHUM': {'HU', 'Positiv', 'Role', 'SocRel'},
#  'CIVIL': {'COLL',
#   'Doctrin',
#   'HU',
#   'Milit',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowAuPt',
#   'PowAuth',
#   'PowCon',
#   'PowDoct',
#   'PowTot',
#   'Pstv',
#   'Ritual',
#   'Role'},
#  'CIVILITY': {'Active', 'Positiv', 'Virtue'},
#  'CIVILIZATION': {'ABS', 'Abs@', 'ArenaLw', 'Doctrin', 'Positiv', 'Pstv'},
#  'CIVILIZE': {'Doctrin',
#   'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Work'},
#  'CLARIFY': {'Active',
#   'ComForm',
#   'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv'},
#  'CLARITY': {'EnlOth', 'EnlTot', 'Ovrst', 'Positiv', 'Pstv', 'Quality'},
#  'CLASSIC': {'Academ', 'COM', 'ComForm', 'Positiv', 'Pstv'},
#  'CLEAN': {'Active',
#   'ECON',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Virtue',
#   'Work'},
#  'CLEANLINESS': {'Positiv', 'Virtue', 'Work'},
#  'CLEANSE': {'Active', 'DAV', 'Positiv', 'Work'},
#  'CLEAR': {'ComForm',
#   'ECON',
#   'Econ@',
#   'EnlOth',
#   'EnlTot',
#   'Exert',
#   'IAV',
#   'Know',
#   'Land',
#   'Ovrst',
#   'PLACE',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Quality',
#   'Quan',
#   'RcGain',
#   'RcTot',
#   'Social',
#   'Solve',
#   'WltOth',
#   'WltTot'},
#  'CLEARNESS': {'Know', 'Perceiv', 'Positiv'},
#  'CLEVER': {'EVAL', 'Positiv', 'Pstv', 'SklOth', 'SklToT', 'Strong', 'Virtue'},
#  'CLOSENESS': {'Positiv', 'SocRel', 'Space'},
#  'CLOUT': {'Positiv', 'Power', 'Strong'},
#  'CO-OPERATION': {'Affil', 'Positiv', 'PowGain', 'PowTot', 'Pstv', 'Virtue'},
#  'COAX': {'Active', 'ComForm', 'IAV', 'Positiv', 'SocRel'},
#  'CODDLE': {'Active', 'Affil', 'IAV', 'Positiv', 'SocRel'},
#  'COEXISTENCE': {'Doctrin',
#   'POLIT',
#   'Passive',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv'},
#  'COGENT': {'ComForm', 'IndAdj', 'Ovrst', 'Positiv', 'Power', 'Strong'},
#  'COGNIZANCE': {'Ovrst', 'Perceiv', 'Positiv', 'Think'},
#  'COGNIZANT': {'IndAdj', 'Ovrst', 'Perceiv', 'Positiv', 'Think'},
#  'COHERENT': {'IndAdj', 'Ovrst', 'Positiv', 'Rel', 'Strong'},
#  'COHESION': {'Affil', 'Ovrst', 'Positiv', 'Rel', 'Strong'},
#  'COHORT': {'Affil', 'COLL', 'Ovrst', 'Positiv'},
#  'COINCIDENT': {'Active', 'NatrPro', 'Positiv', 'Rel'},
#  'COLLABORATE': {'Active', 'Affil', 'ComForm', 'IAV', 'Positiv', 'SocRel'},
#  'COLLABORATION': {'Active',
#   'Affil',
#   'COM',
#   'POLIT',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'COLLEAGUE': {'Affil', 'HU', 'Positiv', 'PowCoop', 'PowTot', 'Pstv', 'Role'},
#  'COLOSSAL': {'Eval@', 'IndAdj', 'Ovrst', 'Positiv', 'Quality'},
#  'COMEBACK': {'Active', 'Increas', 'Positiv', 'Strong'},
#  'COMEDY': {'Exprsv', 'Positiv', 'Pstv', 'Ritual'},
#  'COMELY': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'COMESTIBLE': {'IndAdj', 'NatrPro', 'Pleasur', 'Positiv'},
#  'COMFORT': {'Affil',
#   'Arousal',
#   'IAV',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'WlbGain',
#   'WlbTot'},
#  'COMFORTABLE': {'EVAL',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'COMIC': {'HU', 'Pleasur', 'Positiv', 'Role', 'Work'},
#  'COMICAL': {'IndAdj', 'Pleasur', 'Positiv'},
#  'COMMEMORATE': {'Active', 'IAV', 'Positiv', 'Ritual'},
#  'COMMEMORATION': {'Positiv', 'Ritual'},
#  'COMMENCEMENT': {'Begin', 'EndsLw', 'Positiv'},
#  'COMMEND': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'RspGain',
#   'RspTot'},
#  'COMMENDABLE': {'Affil',
#   'ComForm',
#   'IndAdj',
#   'Positiv',
#   'RspGain',
#   'RspTot',
#   'Virtue'},
#  'COMMENDATION': {'Affil', 'Positiv', 'Ritual'},
#  'COMMENSURATE': {'Eval@', 'IPadj', 'Positiv', 'Quality', 'Rel'},
#  'COMMISSION': {'Affil',
#   'Know',
#   'Ovrst',
#   'Positiv',
#   'PowAuPt',
#   'PowTot',
#   'Strong'},
#  'COMMITMENT': {'Active',
#   'Affil',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Virtue'},
#  'COMMODIOUS': {'Affil', 'IPadj', 'Ovrst', 'Positiv'},
#  'COMMON': {'Affil',
#   'COLL',
#   'ECON',
#   'EVAL',
#   'Econ@',
#   'EnlOth',
#   'EnlTot',
#   'FREQ',
#   'HU',
#   'Ovrst',
#   'PLACE',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowAuPt',
#   'PowTot',
#   'Pstv',
#   'Social',
#   'Time@',
#   'Virtue'},
#  'COMMONSENSE': {'Know', 'Positiv'},
#  'COMMUNAL': {'Affil', 'IPadj', 'Positiv', 'Social'},
#  'COMMUNE': {'Affil', 'Positiv', 'Social'},
#  'COMMUNICATE': {'COM',
#   'ComForm',
#   'EnlGain',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv'},
#  'COMMUNICATIVE': {'ComForm', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'COMMUNION': {'Affil',
#   'Positiv',
#   'Pstv',
#   'RcRelig',
#   'RcTot',
#   'Relig',
#   'Ritual'},
#  'COMMUNITY': {'Affil',
#   'COLL',
#   'ECON',
#   'HU',
#   'POLIT',
#   'Positiv',
#   'PowAren',
#   'PowTot',
#   'Pstv',
#   'Strong'},
#  'COMPANION': {'AffPt', 'AffTot', 'Affil', 'HU', 'Positiv', 'Pstv', 'Role'},
#  'COMPANIONSHIP': {'AffOth', 'AffTot', 'Affil', 'Positiv'},
#  'COMPANY': {'AffPt',
#   'AffTot',
#   'Affil',
#   'COLL',
#   'ECON',
#   'Econ@',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'WltPt',
#   'WltTot'},
#  'COMPASSION': {'Affil', 'EMOT', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'COMPASSIONATE': {'Affil', 'EMOT', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'COMPATIBLE': {'Affil', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'COMPENSATE': {'Active',
#   'Econ@',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain',
#   'Work'},
#  'COMPENSATION': {'Active', 'ECON', 'Positiv', 'Pstv', 'TrnGain', 'Virtue'},
#  'COMPETENCE': {'Eval@',
#   'Know',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'COMPETENCY': {'Eval@', 'Know', 'Positiv', 'Strong'},
#  'COMPETENT': {'EVAL',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'COMPLEMENT': {'IAV', 'Positiv', 'Pstv', 'Quan', 'Rel', 'RspGain', 'RspTot'},
#  'COMPLEMENTARY': {'Eval@', 'IndAdj', 'Positiv', 'Quality', 'Rel'},
#  'COMPLETE': {'Finish',
#   'IAV',
#   'Ovrst',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Quan',
#   'Strong',
#   'SureLw'},
#  'COMPLETENESS': {'ABS', 'Abs@', 'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'COMPLETION': {'Finish', 'Positiv', 'Pstv'},
#  'COMPLIANCE': {'Affil', 'ComForm', 'Positiv', 'PowCoop', 'PowTot', 'SocRel'},
#  'COMPLIMENT': {'Active', 'Affil', 'ComForm', 'IAV', 'Positiv'},
#  'COMPOSURE': {'Positiv', 'Strong', 'Virtue'},
#  'COMPREHEND': {'Active',
#   'EnlOth',
#   'EnlTot',
#   'Know',
#   'Perceiv',
#   'Positiv',
#   'SV'},
#  'COMPREHENSION': {'EnlGain', 'EnlTot', 'Know', 'Positiv', 'Pstv'},
#  'COMPREHENSIVE': {'Complet', 'IndAdj', 'Ovrst', 'Positiv'},
#  'COMPROMISE': {'IAV',
#   'POLIT',
#   'Passive',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Submit'},
#  'CONCESSION': {'Passive',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Submit',
#   'Weak'},
#  'CONCLUSIVE': {'Complet', 'IndAdj', 'Know', 'Ovrst', 'Positiv'},
#  'CONCUR': {'Active',
#   'Affil',
#   'ComForm',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'SV'},
#  'CONDONE': {'Active', 'Affil', 'Positiv', 'Power', 'RcGain', 'RcTot', 'SV'},
#  'CONDUCIVE': {'Affil', 'IndAdj', 'Positiv', 'Rel', 'TrnGain'},
#  'CONFEDERATION': {'Affil', 'Polit@', 'Positiv', 'SocRel'},
#  'CONFER': {'Active',
#   'ComForm',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Think'},
#  'CONFIDANT': {'Affil', 'HU', 'Positiv', 'Role'},
#  'CONFIDE': {'Affil',
#   'ComForm',
#   'IAV',
#   'Ovrst',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot'},
#  'CONFIDENCE': {'Affil',
#   'ComForm',
#   'EMOT',
#   'Ovrst',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Submit'},
#  'CONFIDENT': {'EMOT',
#   'Ovrst',
#   'Pleasur',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong',
#   'WlbPsyc',
#   'WlbTot'},
#  'CONGENIAL': {'AffOth', 'AffTot', 'Affil', 'IPadj', 'Positiv', 'Virtue'},
#  'CONGRATULATE': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'RspGain',
#   'RspTot'},
#  'CONGRATULATION': {'Affil',
#   'COM',
#   'ComForm',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot'},
#  'CONGRATULATORY': {'Affil', 'ComForm', 'IPadj', 'Positiv'},
#  'CONGREGATE': {'Active', 'Affil', 'COLL', 'IAV', 'Positiv'},
#  'CONJUNCTION': {'Positiv', 'PowCoop', 'PowTot', 'Rel'},
#  'CONJURE': {'Active', 'Begin', 'Exprsv', 'IAV', 'Positiv', 'Strong'},
#  'CONNECT': {'Active', 'IAV', 'Positiv', 'Pstv', 'Space'},
#  'CONQUER': {'Active',
#   'IAV',
#   'Positiv',
#   'PowLoss',
#   'PowTot',
#   'Power',
#   'SocRel',
#   'Strong',
#   'Travel'},
#  'CONQUEROR': {'HU', 'Positiv', 'Power', 'Role', 'SocRel', 'Strong', 'Travel'},
#  'CONQUEST': {'Goal', 'Positiv', 'PowOth', 'PowTot'},
#  'CONSCIENCE': {'ABS',
#   'Abs@',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Virtue'},
#  'CONSCIENTIOUS': {'Positiv', 'Pstv', 'Virtue'},
#  'CONSENSUS': {'Affil', 'ComForm', 'Complet', 'Positiv', 'PowCoop', 'PowTot'},
#  'CONSENT': {'COM',
#   'ComForm',
#   'DAV',
#   'Passive',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Submit'},
#  'CONSERVE': {'Active', 'Fetch', 'IAV', 'MeansLw', 'Positiv', 'Try'},
#  'CONSIDER': {'IAV', 'Means', 'Positiv', 'Pstv', 'Solve'},
#  'CONSIDERATE': {'IPadj', 'Positiv', 'SocRel', 'Virtue'},
#  'CONSIDERATION': {'EnlOth', 'EnlTot', 'Know', 'Means', 'Positiv', 'Pstv'},
#  'CONSIGN': {'Active', 'Fetch', 'IAV', 'Positiv'},
#  'CONSISTENCY': {'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'CONSISTENT': {'EndsLw', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'CONSOLE': {'Active', 'Affil', 'IAV', 'Positiv'},
#  'CONSOLIDATE': {'IAV', 'Persist', 'Positiv', 'Pstv', 'Strong'},
#  'CONSTANCY': {'Positiv'},
#  'CONSTRUCTIVE': {'EVAL', 'EndsLw', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'CONSULT': {'ComForm', 'EnlOth', 'EnlTot', 'IAV', 'Positiv', 'Pstv'},
#  'CONSULTATION': {'COM', 'ComForm', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'CONSUMMATE': {'Active', 'ComForm', 'Complet', 'EndsLw', 'IAV', 'Positiv'},
#  'CONTACT': {'Active',
#   'Affil',
#   'COM',
#   'ComForm',
#   'DAV',
#   'EnlGain',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'TrnGain'},
#  'CONTENT': {'ComnObj',
#   'EMOT',
#   'IAV',
#   'Know',
#   'Object',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'TrnGain',
#   'WlbGain',
#   'WlbTot'},
#  'CONTENTMENT': {'EMOT', 'Pleasur', 'Positiv', 'Stay'},
#  'CONTINUITY': {'ABS',
#   'Abs@',
#   'Active',
#   'Persist',
#   'Positiv',
#   'Rel',
#   'Strong'},
#  'CONTRIBUTE': {'Active',
#   'Affil',
#   'Econ@',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain',
#   'Work'},
#  'CONTRIBUTION': {'Active',
#   'Affil',
#   'ECON',
#   'POLIT',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain'},
#  'CONTRIBUTOR': {'Affil',
#   'HU',
#   'Positiv',
#   'Role',
#   'SocRel',
#   'WltPt',
#   'WltTot'},
#  'CONVENE': {'Active', 'Affil', 'Begin', 'COLL', 'IAV', 'Positiv', 'Travel'},
#  'CONVICTION': {'Positiv', 'Pstv', 'RcGain', 'RcTot', 'Strong', 'Virtue'},
#  'CONVINCE': {'Active',
#   'ComForm',
#   'EnlGain',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'COOPERATE': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'COOPERATION': {'ABS',
#   'Abs@',
#   'Active',
#   'Affil',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'COOPERATIVE': {'Active',
#   'Affil',
#   'COLL',
#   'ECON',
#   'Econ@',
#   'HU',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'COORDINATE': {'Active',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'COORDINATION': {'Affil', 'Positiv', 'Rel', 'Strong', 'Virtue'},
#  'CORDIAL': {'AffOth', 'AffTot', 'IPadj', 'Positiv', 'Virtue'},
#  'CORRECT': {'IAV',
#   'Ovrst',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain',
#   'Virtue',
#   'Work'},
#  'CORRECTION': {'Positiv'},
#  'COUNCIL': {'COLL',
#   'HU',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowAuPt',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'COUNSEL': {'Affil',
#   'ComForm',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'IAV',
#   'Legal',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Role'},
#  'COURAGE': {'ABS',
#   'Abs@',
#   'EMOT',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'COURAGEOUS': {'IndAdj', 'Positiv', 'RspOth', 'RspTot', 'Strong', 'Virtue'},
#  'COURTEOUS': {'Affil', 'ComForm', 'Positiv', 'Pstv', 'Virtue'},
#  'COURTESY': {'Affil', 'Positiv', 'Pstv', 'Ritual', 'Virtue'},
#  'COURTLY': {'Polit@', 'Positiv', 'Pstv', 'Virtue'},
#  'COVENANT': {'Affil', 'ComForm', 'Doctrin', 'Positiv'},
#  'COZY': {'Eval@', 'IndAdj', 'Pleasur', 'Positiv', 'Quality'},
#  'CREATE': {'Active',
#   'Begin',
#   'EndsLw',
#   'Exprsv',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'CREATIVE': {'Active',
#   'EMOT',
#   'EndsLw',
#   'Exprsv',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'CREATIVITY': {'ABS',
#   'Abs@',
#   'Active',
#   'EndsLw',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'CREDENTIALS': {'Affil', 'Eval@', 'Positiv', 'Quality'},
#  'CREDIBILITY': {'Eval@', 'Positiv', 'Quality'},
#  'CREDIBLE': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'CREDIT': {'Academ',
#   'COM',
#   'ComForm',
#   'ECON',
#   'Econ@',
#   'Exch',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'Virtue',
#   'WltOth',
#   'WltTot',
#   'WltTran'},
#  'CRUSADE': {'Affil', 'Polit@', 'Positiv', 'Travel'},
#  'CRUSADER': {'Affil', 'HU', 'Polit@', 'Positiv', 'Role', 'Travel'},
#  'CUDDLE': {'Active', 'IAV', 'Pleasur', 'Positiv'},
#  'CULMINATE': {'Active', 'COLL', 'Complet', 'IAV', 'Positiv'},
#  'CULMINATION': {'COLL', 'Complet', 'Positiv', 'Rel'},
#  'CULTIVATE': {'Active',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'TranLw',
#   'Virtue',
#   'Work'},
#  'CULTIVATION': {'Begin', 'Increas', 'Positiv', 'Rel'},
#  'CULTURE': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'EnlOth',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'CUPID': {'EMOT', 'HU', 'Pleasur', 'Positiv'},
#  'CURE': {'Affil',
#   'Complet',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'WlbGain',
#   'WlbTot'},
#  'CURTSEY': {'Active', 'DAV', 'Positiv', 'SocRel'},
#  'CUTE': {'Eval@', 'IndAdj', 'Positiv', 'Virtue'},
#  'DANCE': {'Active',
#   'AffGain',
#   'AffOth',
#   'AffTot',
#   'DAV',
#   'Exprsv',
#   'Positiv',
#   'Pstv',
#   'Ritual',
#   'Travel'},
#  'DARE': {'EndsLw', 'IAV', 'Positiv', 'Pstv', 'Try'},
#  'DARING': {'Eval@',
#   'IndAdj',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'Strong',
#   'Virtue'},
#  'DARLING': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Eval@',
#   'HU',
#   'IndAdj',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'Virtue'},
#  'DAUNTLESS': {'FREQ', 'IndAdj', 'Positiv', 'Power', 'Strong'},
#  'DAWN': {'ABS',
#   'Begin',
#   'DAV',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Solve',
#   'TIME',
#   'Time@'},
#  'DAZZLE': {'Active', 'IAV', 'Perceiv', 'Positiv', 'Strong'},
#  'DEAL': {'Active',
#   'COM',
#   'ComForm',
#   'ECON',
#   'Econ@',
#   'Hostile',
#   'IAV',
#   'Intrj',
#   'Means',
#   'NegAff',
#   'Negativ',
#   'Ngtv',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowDoct',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Quan',
#   'Ritual',
#   'TranLw',
#   'Work'},
#  'DEAR': {'AffOth', 'AffTot', 'Affil', 'Positiv', 'Pstv', 'SureLw', 'Virtue'},
#  'DECENCY': {'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'DECENT': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'DECIPHER': {'Active', 'ComForm', 'IAV', 'Positiv', 'Solve'},
#  'DECORATE': {'Active', 'Eval@', 'IAV', 'Increas', 'Pleasur', 'Positiv'},
#  'DECORATION': {'Object', 'Pleasur', 'Positiv'},
#  'DECORATIVE': {'Eval@', 'IndAdj', 'Pleasur', 'Positiv'},
#  'DEDICATE': {'IAV', 'Need', 'PosAff', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'DEDICATION': {'ABS',
#   'Abs@',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'DEDUCE': {'Active', 'IAV', 'Positiv', 'Solve', 'Think'},
#  'DEFEND': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'DEFENDER': {'Active', 'Affil', 'HU', 'Positiv', 'Pstv', 'Role', 'Strong'},
#  'DEFENSE': {'Active',
#   'Affil',
#   'POLIT',
#   'Positiv',
#   'PowCon',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'DEFERENCE': {'Ought', 'Positiv'},
#  'DEFINITIVE': {'Complet', 'IndAdj', 'Know', 'Positiv', 'Strong', 'SureLw'},
#  'DELICACY': {'Eval@', 'Ovrst', 'Positiv', 'Quality'},
#  'DELICATE': {'EVAL', 'Positiv', 'Pstv', 'Quality', 'Weak'},
#  'DELIGHT': {'EMOT', 'IAV', 'Pleasur', 'Positiv', 'Pstv', 'WlbGain', 'WlbTot'},
#  'DELIGHTFUL': {'EVAL', 'Pleasur', 'Positiv', 'Pstv', 'WlbPsyc', 'WlbTot'},
#  'DEPENDABILITY': {'Ovrst', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'DEPENDABLE': {'Ovrst', 'PosAff', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'DESCRY': {'Active', 'IAV', 'Perceiv', 'Positiv'},
#  'DESERVE': {'Affil', 'IAV', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'SocRel'},
#  'DESERVEDLY': {'Ought', 'Positiv', 'Strong'},
#  'DESIRABLE': {'EVAL', 'EndsLw', 'Positiv', 'Pstv', 'Virtue'},
#  'DESIROUS': {'Eval@', 'IndAdj', 'Need', 'Positiv', 'Quality'},
#  'DEVOTE': {'Active',
#   'AffGain',
#   'AffOth',
#   'AffTot',
#   'EMOT',
#   'IAV',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'Submit',
#   'Try'},
#  'DEVOTION': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'EMOT',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Relig',
#   'Submit'},
#  'DEVOUT': {'Affil', 'Doctrin', 'IndAdj', 'Positiv', 'Strong'},
#  'DEXTERITY': {'Positiv', 'Strong', 'Vary'},
#  'DIG': {'Active',
#   'DAV',
#   'EnlGain',
#   'EnlTot',
#   'Exert',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Solve'},
#  'DIGNIFIED': {'IndAdj', 'Positiv', 'Power', 'Strong'},
#  'DIGNIFY': {'Active', 'ComForm', 'IAV', 'Positiv'},
#  'DIGNITY': {'ABS',
#   'Abs@',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'DILIGENT': {'Active',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'DISCERN': {'Active', 'Eval@', 'IAV', 'Perceiv', 'Positiv', 'Solve'},
#  'DISCREET': {'Positiv', 'Pstv', 'Virtue'},
#  'DISCRETION': {'Positiv', 'Pstv', 'Virtue'},
#  'DISCUSS': {'ComForm', 'EnlOth', 'EnlTot', 'IAV', 'Positiv', 'Pstv'},
#  'DISTINCT': {'EnlOth', 'EnlTot', 'Ovrst', 'Perceiv', 'Positiv', 'Pstv'},
#  'DISTINCTION': {'EnlOth', 'EnlTot', 'Know', 'Positiv', 'Pstv'},
#  'DISTINCTIVE': {'EVAL', 'EnlOth', 'EnlTot', 'Perceiv', 'Positiv', 'Pstv'},
#  'DISTINGUISH': {'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Solve',
#   'Virtue'},
#  'DISTINGUISHED': {'IndAdj', 'Positiv', 'Power', 'Strong'},
#  'DIVINE': {'EVAL',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RcRelig',
#   'RcTot',
#   'Relig',
#   'Solve',
#   'Strong',
#   'Virtue'},
#  'DIVINITY': {'Positiv',
#   'Pstv',
#   'RcRelig',
#   'RcTot',
#   'Relig',
#   'Strong',
#   'Virtue'},
#  'DOMINANCE': {'Positiv', 'Power'},
#  'DONATE': {'Active', 'DAV', 'Econ@', 'Exch', 'Exprsv', 'Fetch', 'Positiv'},
#  'DONATION': {'Econ@', 'Exch', 'Exprsv', 'Fetch', 'Positiv'},
#  'DOTE': {'Active', 'IAV', 'Pleasur', 'Positiv'},
#  'DOUBTLESS': {'Ovrst', 'Positiv', 'Pstv', 'Strong', 'SureLw', 'Virtue'},
#  'DREAMLAND': {'Perceiv', 'Pleasur', 'Positiv', 'Think'},
#  'DURABILITY': {'Positiv', 'Stay', 'Strong'},
#  'DURABLE': {'Means', 'Positiv', 'Pstv', 'Strong', 'WlbPhys', 'WlbTot'},
#  'DYNAMIC': {'Active',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue',
#   'WlbPsyc',
#   'WlbTot'},
#  'EAGER': {'EMOT', 'Pleasur', 'PosAff', 'Positiv', 'Pstv', 'Strong'},
#  'EAGERNESS': {'Feel', 'Positiv'},
#  'EARNEST': {'Pleasur', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Strong'},
#  'EARNESTNESS': {'ComForm', 'Feel', 'Positiv'},
#  'EASE': {'Decreas', 'IAV', 'Pleasur', 'Positiv', 'Pstv'},
#  'EASY': {'EVAL', 'Means', 'Positiv', 'Pstv', 'SureLw', 'Virtue'},
#  'ECONOMIZE': {'Active', 'Econ@', 'Exch', 'IAV', 'Positiv'},
#  'ECSTASY': {'EMOT', 'Pleasur', 'Positiv'},
#  'ECSTATIC': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv'},
#  'EDIBLE': {'Eval@', 'IndAdj', 'NatrPro', 'Positiv', 'Quality'},
#  'EDUCATED': {'Academ',
#   'ComForm',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Virtue'},
#  'EDUCATION': {'Academ', 'Doctrin', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'EDUCATIONAL': {'Academ', 'Doctrin', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'EFFECTIVE': {'Active',
#   'EVAL',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'EFFECTIVENESS': {'Active',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'EFFICACY': {'ABS', 'Abs@', 'Active', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'EFFICIENCY': {'ABS',
#   'Abs@',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'EFFICIENT': {'EVAL',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'ELABORATE': {'Active', 'ComForm', 'IAV', 'Increas', 'Positiv'},
#  'ELABORATION': {'ComForm', 'Increas', 'Positiv'},
#  'ELATE': {'EMOT', 'Pleasur', 'Positiv', 'WlbPsyc', 'WlbTot'},
#  'ELEGANCE': {'Positiv', 'Virtue'},
#  'ELEGANT': {'EVAL', 'Positiv', 'Pstv', 'Virtue'},
#  'ELOQUENT': {'EVAL', 'Exprsv', 'IndAdj', 'Positiv', 'Pstv', 'Virtue'},
#  'EMBELLISH': {'Active', 'ComForm', 'IAV', 'Increas', 'Positiv'},
#  'EMBRACE': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'TrnGain'},
#  'EMINENCE': {'Ovrst', 'Positiv', 'Power', 'Strong'},
#  'EMINENT': {'EVAL', 'Positiv', 'Power', 'Pstv', 'Strong', 'Virtue'},
#  'EMPATHY': {'EMOT', 'Positiv'},
#  'EMPOWER': {'Active',
#   'IAV',
#   'Increas',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Power',
#   'Strong'},
#  'EMPOWERMENT': {'Increas', 'Positiv', 'Power', 'Strong'},
#  'ENABLE': {'Complet', 'IAV', 'Positiv', 'Pstv', 'SklOth', 'SklToT', 'Strong'},
#  'ENCHANT': {'Affil', 'IAV', 'Positiv', 'Pstv', 'SocRel', 'Virtue'},
#  'ENCHANTMENT': {'EMOT', 'Pleasur', 'Positiv'},
#  'ENCOURAGE': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'TrnGain',
#   'Virtue'},
#  'ENCOURAGEMENT': {'Active',
#   'Affil',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Virtue'},
#  'ENDEAR': {'Active', 'Affil', 'IAV', 'Pleasur', 'Positiv'},
#  'ENDORSE': {'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'ENDOW': {'Active', 'DAV', 'Econ@', 'Exch', 'Positiv'},
#  'ENDURANCE': {'Ovrst', 'Persist', 'Positiv', 'Strong', 'WlbPhys', 'WlbTot'},
#  'ENERGETIC': {'Active',
#   'EVAL',
#   'Exert',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'ENERGIZE': {'Active', 'IAV', 'Positiv', 'Strong'},
#  'ENGAGE': {'Active',
#   'AffGain',
#   'AffTot',
#   'Affil',
#   'EVAL',
#   'EndsLw',
#   'IAV',
#   'Kin@',
#   'Need',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Rel',
#   'SocRel',
#   'Try'},
#  'ENHANCE': {'Complet', 'IAV', 'Positiv', 'Pstv', 'Strong', 'TrnGain'},
#  'ENHANCEMENT': {'Increas', 'Ovrst', 'Positiv'},
#  'ENJOY': {'Passive', 'Pleasur', 'Positiv', 'Pstv', 'SV', 'WlbPhys', 'WlbTot'},
#  'ENJOYABLE': {'EVAL', 'Positiv', 'Pstv', 'Virtue', 'WlbPsyc', 'WlbTot'},
#  'ENJOYMENT': {'EMOT',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Virtue',
#   'WlbPsyc',
#   'WlbTot'},
#  'ENLIGHTEN': {'EVAL',
#   'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Solve',
#   'Virtue'},
#  'ENLIGHTENMENT': {'EnlOth', 'EnlTot', 'Know', 'Perceiv', 'Positiv'},
#  'ENRICH': {'Active', 'IAV', 'Increas', 'Positiv', 'Strong', 'TrnGain'},
#  'ENRICHMENT': {'Increas', 'Positiv', 'Strong'},
#  'ENSEMBLE': {'COLL', 'HU', 'Positiv'},
#  'ENSURE': {'IAV',
#   'Ovrst',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain'},
#  'ENTERTAIN': {'Active',
#   'Affil',
#   'ComForm',
#   'EVAL',
#   'Exprsv',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel'},
#  'ENTERTAINMENT': {'Exprsv', 'Positiv', 'Pstv', 'Ritual', 'WlbPsyc', 'WlbTot'},
#  'ENTHUSIASM': {'Affil',
#   'EMOT',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPhys',
#   'WlbTot'},
#  'ENTHUSIASTIC': {'Affil',
#   'EMOT',
#   'Feel',
#   'IndAdj',
#   'Pleasur',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'ENTREPRENEURIAL': {'Begin', 'Econ@', 'IndAdj', 'Positiv'},
#  'ENTRUST': {'Active', 'Feel', 'Fetch', 'IAV', 'Positiv', 'TrnGain'},
#  'ENVISION': {'Active', 'IAV', 'Perceiv', 'Positiv'},
#  'EQUALITY': {'ABS',
#   'Abs@',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Virtue'},
#  'EQUITABLE': {'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'EQUITY': {'COM',
#   'ComForm',
#   'ECON',
#   'Econ@',
#   'Legal',
#   'Positiv',
#   'Pstv',
#   'WltOth',
#   'WltTot'},
#  'ESSENTIAL': {'EVAL',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'SureLw',
#   'Virtue'},
#  'ESTABLISH': {'Active',
#   'Complet',
#   'IAV',
#   'Ovrst',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong',
#   'TranLw',
#   'Virtue'},
#  'ESTEEM': {'Eval@', 'Feel', 'Positiv'},
#  'ETHICAL': {'EVAL', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'ETHICS': {'Doctrin', 'Positiv', 'Pstv', 'RcEthic', 'RcTot'},
#  'ETIQUETTE': {'Doctrin', 'Ought', 'Positiv'},
#  'EVEN': {'Hostile',
#   'IAV',
#   'Negativ',
#   'Ngtv',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'RcGain',
#   'RcTot',
#   'SocRel',
#   'SureLw'},
#  'EVERLASTING': {'FREQ', 'IndAdj', 'Positiv', 'Stay', 'Strong'},
#  'EXACT': {'Active',
#   'IAV',
#   'Means',
#   'Ovrst',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'EXALT': {'Eval@', 'IAV', 'Passive', 'Positiv', 'SocRel', 'Submit'},
#  'EXCEL': {'Active', 'IAV', 'Increas', 'Positiv', 'Strong'},
#  'EXCELLENCE': {'EndsLw', 'Positiv', 'Pstv', 'Virtue'},
#  'EXCELLENT': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'EXCITE': {'Active',
#   'IAV',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'EXCITED': {'EMOT',
#   'IAV',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'EXCITEDNESS': {'Pleasur', 'Positiv'},
#  'EXCITEMENT': {'EMOT',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'EXERTION': {'Positiv', 'Work'},
#  'EXHILARATION': {'Pleasur', 'Positiv'},
#  'EXOTIC': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'EXPERIENCE': {'Complet',
#   'EnlGain',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'EXPERT': {'EVAL',
#   'HU',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Role',
#   'SklOth',
#   'SklPt',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'EXQUISITE': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'EXTOL': {'Eval@', 'IAV', 'Passive', 'Positiv', 'SocRel', 'Submit'},
#  'EXTRAORDINARY': {'EVAL',
#   'IndAdj',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'SureLw',
#   'Virtue'},
#  'EXTRAVAGANCE': {'Eval@', 'MeansLw', 'Ovrst', 'Positiv'},
#  'EXUBERANCE': {'Feel', 'Ovrst', 'Positiv'},
#  'EXUBERANT': {'Feel', 'IndAdj', 'Ovrst', 'Positiv'},
# ...
#  'HUMAN': {'AffPt', 'AffTot', 'HU', 'Positiv', 'Pstv', 'Role'},
#  'HUMANITARIAN': {'IndAdj', 'Polit@', 'Positiv', 'Virtue'},
#  'HUMANITY': {'ABS', 'AffPt', 'AffTot', 'COLL', 'HU', 'Positiv', 'Pstv'},
#  'HUMBLE': {'Passive',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Submit',
#   'Virtue',
#   'Weak'},
#  'HUMILITY': {'Positiv', 'RspOth', 'RspTot', 'Virtue'},
#  'HUMOR': {'ABS',
#   'Abs@',
#   'IAV',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'HUMOROUS': {'IndAdj', 'Pleasur', 'Positiv', 'Pstv', 'WlbPsyc', 'WlbTot'},
#  'HYGIENE': {'Positiv'},
#  'IDEAL': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'EndsLw',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'IDEALISM': {'Doctrin', 'Positiv', 'Think'},
#  'IDOL': {'Goal', 'HU', 'Positiv', 'Role'},
#  'IDOLIZE': {'Active', 'Goal', 'Positiv', 'SV'},
#  'ILLUMINATE': {'Active', 'ComForm', 'IAV', 'Ovrst', 'Positiv'},
#  'ILLUSTRIOUS': {'Eval@', 'IndAdj', 'Ovrst', 'Positiv', 'Quality'},
#  'IMAGINATION': {'Exprsv',
#   'Know',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT'},
#  'IMAGINATIVE': {'EVAL',
#   'Exprsv',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Virtue'},
#  'IMMACULATE': {'IndAdj', 'Ovrst', 'Positiv', 'Virtue'},
#  'IMMORTAL': {'IndAdj', 'Ovrst', 'Positiv', 'Power', 'Stay'},
#  'IMPARTIAL': {'Arousal', 'IndAdj', 'Know', 'Positiv', 'RcEthic', 'RcTot'},
#  'IMPARTIALITY': {'Arousal', 'Know', 'Positiv'},
#  'IMPERATIVE': {'EndsLw', 'Eval@', 'IndAdj', 'Ought', 'Positiv'},
#  'IMPERVIOUS': {'IndAdj', 'Positiv', 'Quality', 'Strong'},
#  'IMPETUS': {'Causal', 'Positiv', 'Strong'},
#  'IMPORTANCE': {'EndsLw', 'Know', 'Ovrst', 'Positiv', 'Pstv'},
#  'IMPORTANT': {'EVAL', 'EndsLw', 'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'IMPRESS': {'Active',
#   'EndsLw',
#   'IAV',
#   'Passive',
#   'Perceiv',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong'},
#  'IMPRESSIVE': {'EVAL',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'IMPROVE': {'Active',
#   'IAV',
#   'Increas',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain',
#   'Virtue',
#   'Work'},
#  'IMPROVEMENT': {'Active', 'Positiv', 'Pstv', 'Strong', 'TrnGain', 'Virtue'},
#  'IMPUNITY': {'Legal', 'Positiv', 'Power'},
#  'INAUGURATE': {'Active', 'Affil', 'Begin', 'IAV', 'Positiv', 'Ritual'},
#  'INAUGURATION': {'Positiv', 'Ritual'},
#  'INDEPENDENCE': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Strong'},
#  'INDEPENDENT': {'Doctrin',
#   'HU',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowOth',
#   'PowPt',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Role',
#   'Strong',
#   'Virtue'},
#  'INDESCRIBABLE': {'ComForm',
#   'Eval@',
#   'IndAdj',
#   'Negate',
#   'Positiv',
#   'Quality'},
#  'INDICATIVE': {'Causal', 'ComForm', 'IndAdj', 'Positiv'},
#  'INDISPENSABILITY': {'Positiv', 'Power', 'Strong', 'Virtue'},
#  'INDISPENSABLE': {'EndsLw', 'Means', 'Ovrst', 'Positiv', 'Pstv', 'Strong'},
#  'INDIVIDUALITY': {'Ovrst', 'Positiv', 'RspOth', 'RspTot'},
#  'INDOMITABLE': {'IndAdj', 'Positiv', 'Power', 'Strong'},
#  'INDULGENCE': {'Arousal', 'Ovrst', 'Pleasur', 'Positiv'},
#  'INDUSTRIOUS': {'IndAdj',
#   'Positiv',
#   'Strong',
#   'Try',
#   'WltOth',
#   'WltTot',
#   'Work'},
#  'INEXPENSIVE': {'Econ@', 'IndAdj', 'Negate', 'Positiv'},
#  'INFALLIBILITY': {'Know', 'Positiv', 'Strong', 'Virtue'},
#  'INFALLIBLE': {'Negate',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'SureLw',
#   'Virtue'},
#  'INFER': {'Active', 'IAV', 'Know', 'Positiv', 'Think'},
#  'INFERENCE': {'Know', 'Positiv', 'Think'},
#  'INFORM': {'Active',
#   'ComForm',
#   'EVAL',
#   'EnlGain',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'Passive',
#   'Positiv',
#   'Pstv'},
#  'INGENIOUS': {'IndAdj', 'Know', 'Positiv', 'Virtue'},
#  'INGENUITY': {'Know', 'Positiv', 'Think', 'Try'},
#  'INHERIT': {'DAV', 'Econ@', 'Exch', 'Passive', 'Positiv'},
#  'INNOCENCE': {'ABS', 'Abs@', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'INNOCENT': {'EVAL',
#   'Legal',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Virtue'},
#  'INNOVATE': {'Active', 'Begin', 'IAV', 'Positiv'},
#  'INNOVATIVE': {'Begin', 'Positiv', 'Virtue'},
#  'INQUISITIVE': {'ComForm', 'IndAdj', 'Positiv', 'Think'},
#  'INSEPARABLE': {'Affil', 'IPadj', 'Negate', 'Positiv', 'SocRel'},
#  'INSIGHT': {'ABS',
#   'Abs@',
#   'EnlOth',
#   'EnlTot',
#   'Know',
#   'Passive',
#   'Positiv',
#   'Pstv'},
#  'INSISTENT': {'Arousal',
#   'ComForm',
#   'IndAdj',
#   'Know',
#   'Positiv',
#   'Strong',
#   'SureLw'},
#  'INSPIRATION': {'Arousal', 'EnlOth', 'EnlTot', 'Goal', 'Positiv'},
#  'INSPIRATIONAL': {'Arousal', 'Goal', 'IndAdj', 'Positiv'},
#  'INSPIRE': {'Active',
#   'Affil',
#   'EVAL',
#   'IAV',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'INSTINCTIVE': {'IndAdj', 'Know', 'NatrPro', 'Positiv'},
#  'INTEGRITY': {'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Strong', 'Virtue'},
#  'INTELLECT': {'Academ',
#   'EnlOth',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'INTELLECTUAL': {'Academ',
#   'EnlOth',
#   'EnlPt',
#   'EnlTot',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'Strong',
#   'Virtue'},
#  'INTELLIGENCE': {'ABS',
#   'Abs@',
#   'Academ',
#   'EnlOth',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'INTELLIGENT': {'EVAL',
#   'EnlOth',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'INTELLIGIBLE': {'ComForm', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'INTERCEDE': {'Active', 'Exert', 'IAV', 'Positiv', 'SocRel'},
#  'INTERCOURSE': {'Active', 'DAV', 'NatrPro', 'Positiv', 'SocRel', 'TranLw'},
#  'INTEREST': {'COM',
#   'ComForm',
#   'ECON',
#   'EMOT',
#   'EVAL',
#   'Econ@',
#   'EndsLw',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Need',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'WltOth',
#   'WltTot'},
#  'INTERESTED': {'EndsLw',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Need',
#   'Passive',
#   'Positiv',
#   'Pstv'},
#  'INTERPOSE': {'Active', 'Exert', 'IAV', 'Positiv', 'SocRel'},
#  'INTIMACY': {'AffOth', 'AffTot', 'EMOT', 'Pleasur', 'Positiv', 'SocRel'},
#  'INTIMATE': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'Passive',
#   'Positiv',
#   'Pstv'},
#  'INTRICATE': {'IndAdj', 'Ovrst', 'Positiv'},
#  'INTRIGUE': {'IAV', 'Passive', 'Positiv', 'PowCon', 'PowTot', 'Think'},
#  'INVALUABLE': {'Econ@', 'Eval@', 'IndAdj', 'PosAff', 'Positiv', 'Quality'},
#  'INVENTOR': {'Active', 'HU', 'Positiv', 'Pstv', 'Role', 'SklPt', 'SklToT'},
#  'INVINCIBLE': {'IndAdj',
#   'Negate',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Strong',
#   'Virtue'},
#  'INVITATION': {'Active',
#   'Affil',
#   'COM',
#   'ComForm',
#   'Positiv',
#   'Pstv',
#   'TrnGain'},
#  'INVITE': {'Active',
#   'Affil',
#   'DAV',
#   'EVAL',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain',
#   'Virtue'},
#  'INVULNERABLE': {'IndAdj', 'Negate', 'Positiv', 'Power', 'Strong', 'Virtue'},
#  'IRRESISTIBLE': {'Eval@', 'IPadj', 'Need', 'Negate', 'Positiv'},
#  'JEST': {'Active', 'ComForm', 'IAV', 'Pleasur', 'Positiv'},
#  'JOIN': {'Active',
#   'Affil',
#   'DAV',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Rel',
#   'SocRel',
#   'Strong',
#   'TranLw'},
#  'JOINTLY': {'Affil', 'Positiv', 'PowCoop', 'PowTot', 'Pstv', 'Rel', 'Strong'},
#  'JOKE': {'ComForm', 'Exprsv', 'IAV', 'Positiv', 'Pstv'},
#  'JOLLY': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv'},
#  'JOY': {'EMOT', 'Pleasur', 'Positiv', 'Pstv', 'WlbPsyc', 'WlbTot'},
#  'JOYFUL': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv', 'WlbPsyc', 'WlbTot'},
#  'JUBILANT': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv', 'WlbPsyc', 'WlbTot'},
#  'JUBILEE': {'Pleasur', 'Positiv', 'Ritual'},
#  'JUST': {'Legal',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quan',
#   'RcEthic',
#   'RcTot',
#   'Time@',
#   'Virtue'},
#  'JUSTICE': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'Legal',
#   'POLIT',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RcEthic',
#   'RcTot'},
#  'JUSTIFIABLY': {'Ovrst', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'JUSTIFICATION': {'Ovrst', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'JUSTIFY': {'ComForm', 'IAV', 'Ovrst', 'Positiv', 'Pstv', 'RcGain', 'RcTot'},
#  'KEEN': {'PosAff', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'KID': {'Affil',
#   'ComForm',
#   'Exprsv',
#   'HU',
#   'IAV',
#   'Nonadlt',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'RspOth',
#   'RspTot'},
#  'KIND': {'ABS',
#   'Abs@',
#   'Affil',
#   'ComForm',
#   'EVAL',
#   'Know',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Undrst',
#   'Virtue'},
#  'KINDNESS': {'Affil', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'KISS': {'Active',
#   'AffGain',
#   'AffTot',
#   'Affil',
#   'ComForm',
#   'DAV',
#   'Positiv',
#   'Pstv',
#   'SocRel'},
#  'KNOW': {'Active',
#   'EnlOth',
#   'EnlTot',
#   'Intrj',
#   'Know',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'SV',
#   'Solve'},
#  'KNOWLEDGE': {'ABS',
#   'Abs@',
#   'Academ',
#   'EnlOth',
#   'EnlTot',
#   'Know',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'LAUDABLE': {'Affil', 'Eval@', 'IPadj', 'Positiv', 'Quality'},
#  'LAUGH': {'Active',
#   'COM',
#   'ComForm',
#   'DAV',
#   'Exprsv',
#   'Hostile',
#   'IAV',
#   'Negativ',
#   'Ngtv',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'RspLoss',
#   'RspTot',
#   'Undrst',
#   'WlbPsyc',
#   'WlbTot'},
#  'LAUGHTER': {'COM',
#   'ComForm',
#   'Exprsv',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'LAVISH': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'LAW': {'Doctrin', 'Legal', 'POLIT', 'Positiv', 'PowAuth', 'PowTot', 'Pstv'},
#  'LAWFUL': {'IndAdj', 'Legal', 'Positiv', 'PowAuth', 'PowTot', 'Virtue'},
#  'LEAD': {'Active',
#   'Causal',
#   'ComForm',
#   'EVAL',
#   'Hostile',
#   'IAV',
#   'Means',
#   'Ovrst',
#   'Persist',
#   'PosAff',
#   'Positiv',
#   'PowCon',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TranLw',
#   'Virtue',
#   'WlbPhys',
#   'WlbTot'},
#  'LEARN': {'ABS',
#   'Abs@',
#   'Academ',
#   'Active',
#   'EnlEnds',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Solve',
#   'Virtue'},
#  'LEARNER': {'Academ',
#   'EnlPt',
#   'EnlTot',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'Submit'},
#  'LEGAL': {'Doctrin',
#   'ECON',
#   'Legal',
#   'POLIT',
#   'Positiv',
#   'PowAuth',
#   'PowTot',
#   'Pstv'},
#  'LEGITIMACY': {'Legal', 'Positiv', 'Virtue'},
#  'LEGITIMATE': {'Legal', 'Positiv', 'PowAuth', 'PowTot', 'Pstv', 'Virtue'},
#  'LEISURE': {'Exprsv', 'Passive', 'Positiv', 'Pstv', 'Virtue'},
#  'LIBERAL': {'Academ',
#   'Affil',
#   'Doctrin',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Role',
#   'Virtue'},
#  'LIBERALISM': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowDoct',
#   'PowTot',
#   'Pstv'},
#  'LIBERATE': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'Power',
#   'RcEthic',
#   'RcTot'},
#  'LIBERTY': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'Polit@',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Pstv'},
#  'LIFELONG': {'IndAdj', 'Positiv', 'Stay'},
#  'LIGHT': {'Active',
#   'ComForm',
#   'DAV',
#   'EnlOth',
#   'EnlTot',
#   'Exert',
#   'IAV',
#   'Know',
#   'NatrPro',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'TranLw',
#   'Undrst',
#   'Weak'},
#  'LIKABLE': {'Eval@', 'IPadj', 'Positiv', 'Quality', 'Virtue'},
#  'LIKE': {'AffGain',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'EMOT',
#   'Passive',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Rel',
#   'SV'},
#  'LIVE': {'Complet',
#   'ECON',
#   'Econ@',
#   'IAV',
#   'Means',
#   'NatrPro',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'SV',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'LIVELY': {'Active',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'LOGIC': {'EnlOth', 'EnlTot', 'Know', 'Positiv', 'Pstv'},
#  'LOGICAL': {'EnlOth', 'EnlTot', 'Know', 'Positiv', 'Pstv'},
#  'LONGEVITY': {'Positiv', 'Stay', 'Strong'},
#  'LOVE': {'Active',
#   'AffGain',
#   'AffOth',
#   'AffTot',
#   'Affil',
#   'EMOT',
#   'IAV',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'SV',
#   'SocRel',
#   'Strong'},
#  'LOVELINESS': {'Positiv', 'Virtue'},
#  'LOVELY': {'EVAL', 'Positiv', 'Pstv', 'SklAsth', 'SklToT', 'Virtue'},
#  'LOVER': {'AffPt', 'AffTot', 'Affil', 'HU', 'Positiv', 'Pstv', 'Role'},
#  'LOYAL': {'AffOth',
#   'AffTot',
#   'Polit@',
#   'Positiv',
#   'Pstv',
#   'Submit',
#   'Virtue'},
#  'LOYALTY': {'ABS',
#   'Abs@',
#   'AffOth',
#   'AffTot',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'Pstv',
#   'Submit',
#   'Virtue'},
#  'LUCID': {'ComForm', 'IndAdj', 'Ovrst', 'Positiv'},
#  'LUCK': {'ABS',
#   'Abs@',
#   'EndsLw',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Undrst',
#   'Virtue'},
#  'LUCKILY': {'EndsLw', 'Positiv', 'Pstv', 'Undrst', 'Virtue'},
#  'LUCKY': {'EndsLw', 'Passive', 'Positiv', 'Pstv', 'Virtue'},
#  'LUCRATIVE': {'Econ@', 'Exch', 'Increas', 'IndAdj', 'Positiv'},
#  'LUMINOUS': {'IndAdj', 'Ovrst', 'Positiv'},
#  'LUST': {'EMOT', 'Need', 'Pleasur', 'Positiv'},
#  'LUSTER': {'Positiv', 'Quality'},
#  'LUSTROUS': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'LUXURIANT': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'LUXURIOUS': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'LUXURY': {'ECON', 'Econ@', 'Positiv', 'Pstv', 'Virtue', 'WltOth', 'WltTot'},
#  'LYRIC': {'COM', 'ComForm', 'Exprsv', 'Positiv', 'Pstv'},
#  'LYRICAL': {'ComForm', 'Exprsv', 'Positiv', 'Pstv'},
#  'MAGICAL': {'Eval@', 'IndAdj', 'Positiv', 'Quality', 'Relig'},
#  'MAGNETIC': {'IPadj', 'NatrPro', 'Positiv', 'Rel'},
#  'MAGNIFICENCE': {'Ovrst', 'Positiv', 'Virtue'},
#  'MAGNIFICENT': {'EVAL',
#   'Ovrst',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'MAIN': {'EVAL', 'Know', 'Ovrst', 'Positiv', 'Pstv', 'Strong', 'SureLw'},
#  'MAJESTIC': {'IndAdj', 'Ovrst', 'Positiv', 'Virtue'},
#  'MAJESTY': {'Positiv', 'Virtue'},
#  'MAJOR': {'Academ',
#   'Doctrin',
#   'EVAL',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Know',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Work'},
#  'MAKE': {'Active',
#   'Affil',
#   'Complet',
#   'Hostile',
#   'IAV',
#   'Means',
#   'Negativ',
#   'Ngtv',
#   'Object',
#   'Perceiv',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Solve',
#   'Strong',
#   'Tool',
#   'Work'},
#  'MANAGEABLE': {'Causal', 'IndAdj', 'Ovrst', 'Positiv', 'Strong'},
#  'MANLY': {'IndAdj',
#   'MALE',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue',
#   'WlbPsyc',
#   'WlbTot'},
#  'MARITAL': {'AffOth', 'AffTot', 'Kin@', 'Positiv', 'Pstv', 'Ritual'},
#  'MARRIAGE': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Kin@',
#   'Positiv',
#   'Pstv',
#   'Ritual'},
#  'MARRY': {'AffGain',
#   'AffOth',
#   'AffTot',
#   'Affil',
#   'DAV',
#   'Kin@',
#   'Positiv',
#   'Pstv',
#   'SocRel'},
#  'MARVEL': {'Active', 'IAV', 'Ovrst', 'Positiv', 'Think'},
#  'MARVELOUS': {'IndAdj', 'PosAff', 'Positiv', 'Think', 'Virtue'},
#  'MASTERFUL': {'IndAdj', 'Know', 'Positiv', 'Power', 'Strong'},
#  'MASTERY': {'Know', 'Positiv', 'Strong'},
#  'MATCHLESS': {'IndAdj', 'Negate', 'Ovrst', 'Positiv'},
#  'MATE': {'AffGain',
#   'AffPt',
#   'AffTot',
#   'Affil',
#   'DAV',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'SocRel'},
#  'MATTER': {'ABS',
#   'COM',
#   'EVAL',
#   'EndsLw',
#   'IAV',
#   'Know',
#   'NegAff',
#   'Negativ',
#   'Ngtv',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Solve',
#   'Strong',
#   'SureLw',
#   'Undrst',
#   'Vice'},
#  'MATURE': {'IAV',
#   'Increas',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'MATURITY': {'ABS',
#   'Abs@',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Time@'},
#  'MAXIMIZE': {'Active', 'IAV', 'Increas', 'Positiv'},
#  'MEANINGFUL': {'EVAL', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv', 'Virtue'},
#  'MEASURABLE': {'IndAdj', 'Positiv', 'Quan'},
#  'MEDIATE': {'Active',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'SocRel',
#   'Solve'},
#  'MEDITATION': {'Arousal', 'Positiv', 'Think'},
#  'MEET': {'Active',
#   'Affil',
#   'COM',
#   'ComForm',
#   'DAV',
#   'Exch',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Ritual',
#   'SocRel',
#   'Solve',
#   'TranLw',
#   'WltOth',
#   'WltTot'},
#  'MELLOW': {'Arousal', 'IndAdj', 'Positiv'},
#  'MELODY': {'COM',
#   'ComForm',
#   'Exprsv',
#   'Positiv',
#   'Pstv',
#   'SklAsth',
#   'SklToT'},
#  'MEMORABLE': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'MEND': {'Active', 'IAV', 'Positiv', 'Pstv', 'TrnGain', 'Work'},
#  'MENTOR': {'HU', 'Know', 'Positiv', 'Power', 'Role'},
#  'MERCIFUL': {'IPadj', 'Positiv', 'Virtue'},
#  'MERCY': {'ABS', 'Abs@', 'AffGain', 'AffTot', 'Positiv', 'Pstv', 'Virtue'},
#  'MERIT': {'Affil',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'MERITORIOUS': {'Econ@', 'Goal', 'IndAdj', 'Positiv', 'Virtue'},
#  'MERRILY': {'EMOT', 'Pleasur', 'Positiv'},
#  'MERRIMENT': {'EMOT', 'Pleasur', 'Positiv'},
#  ...}

# %%
# Create a dataframe to store all the values
MCA_Dataframe = pd.DataFrame(index=textName)

# Insert the tokenized data
MCA_Dataframe.insert(loc=0, column='tokens', value=text_clean_tokenized)

# Count the number of times each category appears in the text based on the their tokens
MCA_Dataframe = MCA_Dataframe.apply(update_values_category, axis=1)

# Remove the tokens frame as we are done with it now
MCA_Dataframe = MCA_Dataframe.drop("tokens", axis=1)

# Replace any empty cell with 0
MCA_Dataframe = MCA_Dataframe.fillna(0)

# Have a look at what the dataframe looks like
MCA_Dataframe
# Out:
#                                         Positiv  Negativ   Pstv  Affil  Ngtv  \
# Berkeley_AlciphronCLEAN                    6484     3350   5992   2741  2902
# Berkeley_HumanKnowledgeCLEAN               2075     1250   1922   1068  1123
# Berkeley_TheoryOfVisionCLEAN               1261      942   1186    727   896
# Berkeley_ThreeDialoguesCLEAN               2381     1574   2316   1234  1446
# Hume_EssaysMoralPoliticalLiteraryCLEAN    15187     8912  12964   6480  7177
# Hume_HumanUnderstandingCLEAN               3699     2096   3198   1675  1816
# Hume_NaturalReligionCLEAN                  2747     1734   2459   1202  1511
# Hume_SourcesofMoralsCLEAN                  4684     2389   4158   2176  1933
# Locke_HumanUnderstandingCLEAN             17341     9806  15929   9810  8792
# Locke_TwoTreatisesCLEAN                    6106     3116   5122   3198  2574
#
#                                         Hostile  Strong  Power  Weak  Submit  \
# Berkeley_AlciphronCLEAN                    1984    7007   3618  2503    1331
# Berkeley_HumanKnowledgeCLEAN                773    2791   1339  1113     558
# Berkeley_TheoryOfVisionCLEAN                653    2039    826   750     341
# Berkeley_ThreeDialoguesCLEAN                988    3018   1472  1182     707
# Hume_EssaysMoralPoliticalLiteraryCLEAN     4747   21184  10371  6496    2551
# Hume_HumanUnderstandingCLEAN               1289    4996   2202  1514     664
# Hume_NaturalReligionCLEAN                   993    3986   1659  1297     505
# Hume_SourcesofMoralsCLEAN                  1278    4653   2096  1522     623
# Locke_HumanUnderstandingCLEAN              5888   25481  11736  8851    4611
# Locke_TwoTreatisesCLEAN                    2213   11530   7512  2759    1542
#
#                                          ...    PtLw  Nation  Anomie  NegAff  \
# Berkeley_AlciphronCLEAN                  ...    1243     214      15     527
# Berkeley_HumanKnowledgeCLEAN             ...     522      57       0     152
# Berkeley_TheoryOfVisionCLEAN             ...     293      47       0      86
# Berkeley_ThreeDialoguesCLEAN             ...     318      22       3     267
# Hume_EssaysMoralPoliticalLiteraryCLEAN   ...    2741    1602      61    1241
# Hume_HumanUnderstandingCLEAN             ...     563      55       9     221
# Hume_NaturalReligionCLEAN                ...     432      77      22     251
# Hume_SourcesofMoralsCLEAN                ...     799      79      10     321
# Locke_HumanUnderstandingCLEAN            ...    4351     545      20    1146
# Locke_TwoTreatisesCLEAN                  ...    1931     171      12     396
#
#                                         PosAff  SureLw  If  NotLw  TimeSpc  \
# Berkeley_AlciphronCLEAN                    967    2813   0      0        0
# Berkeley_HumanKnowledgeCLEAN               199    1394   0      0        0
# Berkeley_TheoryOfVisionCLEAN               107     890   0      0        0
# Berkeley_ThreeDialoguesCLEAN               267    1569   0      0        0
# Hume_EssaysMoralPoliticalLiteraryCLEAN    1659    6875   0      0        0
# Hume_HumanUnderstandingCLEAN               321    1923   0      0        0
# Hume_NaturalReligionCLEAN                  348    1461   0      0        0
# Hume_SourcesofMoralsCLEAN                  689    1698   0      0        0
# Locke_HumanUnderstandingCLEAN             1651   10354   0      0        0
# Locke_TwoTreatisesCLEAN                    626    3541   0      0        0
#
#                                         FormLw
# Berkeley_AlciphronCLEAN                      0
# Berkeley_HumanKnowledgeCLEAN                 0
# Berkeley_TheoryOfVisionCLEAN                 0
# Berkeley_ThreeDialoguesCLEAN                 0
# Hume_EssaysMoralPoliticalLiteraryCLEAN       0
# Hume_HumanUnderstandingCLEAN                 0
# Hume_NaturalReligionCLEAN                    0
# Hume_SourcesofMoralsCLEAN                    0
# Locke_HumanUnderstandingCLEAN                0
# Locke_TwoTreatisesCLEAN                      0
#
# [10 rows x 182 columns]

# %%
# Divide each cell by the sum of the row
MCA_Dataframe.loc[:,:] = MCA_Dataframe.loc[:,:].div(MCA_Dataframe.sum(axis=1), axis=0)

# See the results
MCA_Dataframe
# Out:
#                                          Positiv   Negativ      Pstv  \
# Berkeley_AlciphronCLEAN                 0.028885  0.014923  0.026693
# Berkeley_HumanKnowledgeCLEAN            0.023429  0.014114  0.021702
# Berkeley_TheoryOfVisionCLEAN            0.018302  0.013672  0.017214
# Berkeley_ThreeDialoguesCLEAN            0.024086  0.015922  0.023428
# Hume_EssaysMoralPoliticalLiteraryCLEAN  0.027183  0.015951  0.023204
# Hume_HumanUnderstandingCLEAN            0.027393  0.015522  0.023683
# Hume_NaturalReligionCLEAN               0.026747  0.016883  0.023942
# Hume_SourcesofMoralsCLEAN               0.033859  0.017269  0.030056
# Locke_HumanUnderstandingCLEAN           0.023850  0.013487  0.021908
# Locke_TwoTreatisesCLEAN                 0.021966  0.011210  0.018426
#
#                                            Affil      Ngtv   Hostile  \
# Berkeley_AlciphronCLEAN                 0.012210  0.012928  0.008838
# Berkeley_HumanKnowledgeCLEAN            0.012059  0.012680  0.008728
# Berkeley_TheoryOfVisionCLEAN            0.010552  0.013005  0.009478
# Berkeley_ThreeDialoguesCLEAN            0.012483  0.014627  0.009994
# Hume_EssaysMoralPoliticalLiteraryCLEAN  0.011598  0.012846  0.008496
# Hume_HumanUnderstandingCLEAN            0.012404  0.013449  0.009546
# Hume_NaturalReligionCLEAN               0.011703  0.014712  0.009668
# Hume_SourcesofMoralsCLEAN               0.015729  0.013973  0.009238
# Locke_HumanUnderstandingCLEAN           0.013492  0.012092  0.008098
# Locke_TwoTreatisesCLEAN                 0.011505  0.009260  0.007961
#
#                                           Strong     Power      Weak  \
# Berkeley_AlciphronCLEAN                 0.031215  0.016117  0.011150
# Berkeley_HumanKnowledgeCLEAN            0.031514  0.015119  0.012567
# Berkeley_TheoryOfVisionCLEAN            0.029594  0.011989  0.010886
# Berkeley_ThreeDialoguesCLEAN            0.030530  0.014890  0.011957
# Hume_EssaysMoralPoliticalLiteraryCLEAN  0.037916  0.018563  0.011627
# Hume_HumanUnderstandingCLEAN            0.036998  0.016307  0.011212
# Hume_NaturalReligionCLEAN               0.038810  0.016153  0.012628
# Hume_SourcesofMoralsCLEAN               0.033635  0.015151  0.011002
# Locke_HumanUnderstandingCLEAN           0.035045  0.016141  0.012173
# Locke_TwoTreatisesCLEAN                 0.041478  0.027024  0.009925
#
#                                           Submit   ...        PtLw    Nation  \
# Berkeley_AlciphronCLEAN                 0.005929   ...    0.005537  0.000953
# Berkeley_HumanKnowledgeCLEAN            0.006300   ...    0.005894  0.000644
# Berkeley_TheoryOfVisionCLEAN            0.004949   ...    0.004253  0.000682
# Berkeley_ThreeDialoguesCLEAN            0.007152   ...    0.003217  0.000223
# Hume_EssaysMoralPoliticalLiteraryCLEAN  0.004566   ...    0.004906  0.002867
# Hume_HumanUnderstandingCLEAN            0.004917   ...    0.004169  0.000407
# Hume_NaturalReligionCLEAN               0.004917   ...    0.004206  0.000750
# Hume_SourcesofMoralsCLEAN               0.004503   ...    0.005776  0.000571
# Locke_HumanUnderstandingCLEAN           0.006342   ...    0.005984  0.000750
# Locke_TwoTreatisesCLEAN                 0.005547   ...    0.006947  0.000615
#
#                                           Anomie    NegAff    PosAff  \
# Berkeley_AlciphronCLEAN                 0.000067  0.002348  0.004308
# Berkeley_HumanKnowledgeCLEAN            0.000000  0.001716  0.002247
# Berkeley_TheoryOfVisionCLEAN            0.000000  0.001248  0.001553
# Berkeley_ThreeDialoguesCLEAN            0.000030  0.002701  0.002701
# Hume_EssaysMoralPoliticalLiteraryCLEAN  0.000109  0.002221  0.002969
# Hume_HumanUnderstandingCLEAN            0.000067  0.001637  0.002377
# Hume_NaturalReligionCLEAN               0.000214  0.002444  0.003388
# Hume_SourcesofMoralsCLEAN               0.000072  0.002320  0.004980
# Locke_HumanUnderstandingCLEAN           0.000028  0.001576  0.002271
# Locke_TwoTreatisesCLEAN                 0.000043  0.001425  0.002252
#
#                                           SureLw   If  NotLw  TimeSpc  FormLw
# Berkeley_AlciphronCLEAN                 0.012531  0.0    0.0      0.0     0.0
# Berkeley_HumanKnowledgeCLEAN            0.015740  0.0    0.0      0.0     0.0
# Berkeley_TheoryOfVisionCLEAN            0.012918  0.0    0.0      0.0     0.0
# Berkeley_ThreeDialoguesCLEAN            0.015872  0.0    0.0      0.0     0.0
# Hume_EssaysMoralPoliticalLiteraryCLEAN  0.012305  0.0    0.0      0.0     0.0
# Hume_HumanUnderstandingCLEAN            0.014241  0.0    0.0      0.0     0.0
# Hume_NaturalReligionCLEAN               0.014225  0.0    0.0      0.0     0.0
# Hume_SourcesofMoralsCLEAN               0.012274  0.0    0.0      0.0     0.0
# Locke_HumanUnderstandingCLEAN           0.014240  0.0    0.0      0.0     0.0
# Locke_TwoTreatisesCLEAN                 0.012739  0.0    0.0      0.0     0.0
#
# [10 rows x 182 columns]

# %%
# Run MCA on the dataframe (first 10 columns)
mca_test = MCA(MCA_Dataframe.loc[:,:'Submit'], benzecri=False)

# Acquire the factor score for the Authors
Authors_Score = mca_test.fs_r().T

# Acquire the factor score for the Categories
Category_Score = mca_test.fs_c().T

# Returns the variance of each Axis 
Variance = mca_test.L

# Calculate the % variance of total
Variance_total = [Variance[0] / (Variance[0] + Variance[1]), Variance[1] / (Variance[0] + Variance[1])]

# %%
# Set the Author points to be represented by Triangles
plt.scatter(Authors_Score[0], Authors_Score[1], cmap='viridis', s=150, marker = '^', label='Author')

# Set the Category points to be represented by Squares
plt.scatter(Category_Score[0], Category_Score[1], cmap='viridis', s=150, marker = 's', label='Category')

# Set the size of the figure
plt.rcParams["figure.figsize"] = (10,10)

name = ["A", "B", "C"]

# Label each point for Author
for i, txt in enumerate(textName):
    plt.annotate(txt, (Authors_Score[0][i],Authors_Score[1][i]), fontsize = 10, fontweight='bold')

# Label each point for Category
for i, txt in enumerate(categories[:10]):
    plt.annotate(txt, (Category_Score[0][i],Category_Score[1][i]), fontsize = 10, fontweight='bold')

# Draw axis

Axis1_Label= "Axis 1. \n Variance:" + str(format(Variance[0], '.3f')) + " %:" + str(format(Variance_total[0], '.3f'))
Axis2_Label= "Axis 1. \n Variance:" + str(format(Variance[1], '.3f')) + " %:" + str(format(Variance_total[1], '.3f'))
plt.axhline(0, color='black',linestyle=':', label=Axis1_Label)
plt.axvline(0, color='black',linestyle='--', label=Axis2_Label)

# Set Legend
plt.legend(loc='center left', bbox_to_anchor=(1,0.5))    

# Display Graph
plt.show()
